# %%
#https://en.wikisource.org/wiki/Page:Dictionary_of_Greek_and_Roman_Geography_Volume_I_Part_1.djvu/502

import re

rnums = {}
rnums['i'] = 1
rnums['ii'] = 2
rnums['iii'] = 3
rnums['iv'] = 4
rnums['v'] = 5
rnums['vi'] = 6
rnums['vii'] = 7
rnums['viii'] = 8
rnums['ix'] = 9
rnums['x'] = 10
rnums['xi'] = 11
rnums['xii'] = 12
rnums['xiii'] = 13
rnums['xiv'] = 14
rnums['xv'] = 15
rnums['xvi'] = 16
rnums['xvii'] = 17
rnums['xviii'] = 18
rnums['xix'] = 19
rnums['xx'] = 20
rnums['xxi'] = 21
rnums['xxii'] = 22
rnums['xxiii'] = 23
rnums['xxiv'] = 24
rnums['xxv'] = 25
rnums['xxvi'] = 26
rnums['xxvii'] = 27
rnums['xxviii'] = 28
rnums['xxix'] = 29
rnums['xxx'] = 30
rnums['xxxi'] = 31
rnums['xxxii'] = 32
rnums['xxxiii'] = 33
rnums['xxxiv'] = 34
rnums['xxxv'] = 35
rnums['xxxvi'] = 36
rnums['xxxvii'] = 37
rnums['xxxviii'] = 38
rnums['xxxix'] = 39
rnums['xl'] = 40
rnums['xli'] = 41
rnums['xlii'] = 42
rnums['xliii'] = 43
rnums['xliv'] = 44
rnums['xlv'] = 45
rnums['xlvi'] = 46
rnums['xlvii'] = 47
rnums['xlviii'] = 48
rnums['xlix'] = 49
rnums['l'] = 50


j = 0

notyears = ['Argonautica','Dicaearchus','Editions','Epigram','Eutrop','Gennadius','Hephaestion','Liberalis','Lycophron','Petronius','Theogony','appended','chapter','epigrams','wrote']
notyears.append('Apollo')
notyears.append('Aphrodite')
notyears.append('Aristophanes')
notyears.append('Artemis')
notyears.append('Avienus')
notyears.append('Chius')
notyears.append('Demeter')
notyears.append('Festus')
notyears.append('Jornandes')
notyears.append('Obsequens')
notyears.append('Orelli')
notyears.append('Orpheus')
notyears.append('Periegetes')
notyears.append('Phrygius')
notyears.append('Scymnus')
notyears.append('Thesmophoriazusae')

countwords = []
f2 = open('count-words.txt')
for l in f2:
    l = re.sub('\n','',l)
    countwords.append(l)
f2.close()


f2 = open('place-excepts.txt')
placelist = []
for l in f2:
    l = re.sub('^[\s0-9]+','',l)
    if(not re.search('[a-z]',l)):
        continue
    placelist.append(re.sub('\n','',l))
f2.close()


f = open("viaf88890045.002.xml","r")
outf = open('smithgeo-work1.xml','w')
import re
from cltk.corpus.greek.beta_to_unicode import Replacer

r = Replacer()

def fract2dec(s):
    s = re.sub(',','',s)
    m = re.search('([0-9]+)\s+([0-9]+)/([0-9]+)',s)
    if(m):
        basen = int(m[1])
        numerator = int(m[2])
        denom = int(m[3])
        rval = basen + numerator/denom
        #print('fractres',s,rval)
        s = str(rval)
        
    return(s)

shortnames = ['Cos','Cato','Hera','Jew','Jews','Livy','Milo','No','Nos','Num','Otho','Ovid','Piso','Pius','Way','Ways','West','Zeno','Zeus']
shortpat = '('+ '|'.join(shortnames) + ')'

centval = {}
centval["15th B.C."] = "-1500--1401"
centval["thirteenth B.C."] = "-1300--1201"
centval["13th B.C."] = "-1300--1201"
centval["twelfth B.C."] = "-1200--1101"
centval["tenth B.C."] = "-1000--901"
centval["eleventh B.C."] = "-1100--1001"
centval["ninth B.C."] = "-900--801"
centval["8th B.C."] = "-800--701"
centval["eighth B.C."] = "-800--701"
centval["seventh B.C."] = "-700--601"
centval["7th B.C."] = "-700--601"
centval["sixth B.C."] = "-600--501"
centval["6th B.C."] = "-600--501"
centval["5th B.C."] = "-500--401"
centval["fifth B.C."] = "-500--401"
centval["fourth B.C."] = "-400--301"
centval["4th B.C."] = "-400--301"
centval["3rd B.C."] = "-300--201"
centval["third B.C."] = "-300--201"
centval["15th B.C."] = "-1500--1401"
centval["twelfth B.C."] = "-1200--1101"
centval["tenth B.C."] = "-1000--901"
centval["eleventh B.C."] = "-1100--1001"
centval["ninth B.C."] = "-900--801"
centval["8th B.C."] = "-800--701"
centval["eighth B.C."] = "-800--701"
centval["seventh B.C."] = "-700--601"
centval["7th B.C."] = "-700--601"
centval["sixth B.C."] = "-600--501"
centval["6th B.C."] = "-600--501"
centval["5th B.C."] = "-500--401"
centval["fifth B.C."] = "-500--401"
centval["fourth B.C."] = "-400--301"
centval["4th B.C."] = "-400--301"
centval["3rd B.C."] = "-300--201"
centval["third B.C."] = "-300--201"
centval["second B.C."] = "-200--101"
centval["1st B.C."] = "-100--001"
centval["first B.C."] = "-100--001"
centval["a B.C."] = "-100--001"
centval["the B.C."] = "-100--001"
centval["last B.C."] = "-100--001"
centval["first A.D."] = "001-100"
centval["2nd A.D."] = "101-200"
centval["second A.D."] = "101-200"
centval["3rd A.D."] = "201-300"
centval["third A.D."] = "201-300"
centval["4th A.D."] = "301-400"
centval["fourth A.D."] = "301-400"
centval["fifth A.D."] = "401-500"
centval["5th A.D."] = "401-500"
centval["sixth A.D."] = "501-600"
centval["6th A.D."] = "501-600"
centval["seventh A.D."] = "601-700"
centval["7th A.D."] = "601-700"
centval["eighth A.D."] = "701-800"
centval["8th A.D."] = "701-800"
centval["ninth A.D."] = "801-900"

centval["9th A.D."] = "801-900"
centval["10th A.D."] = "901-1000"
centval["tenth A.D."] = "901-1000"
centval["11th A.D."] = "1001-1100"
centval["eleventh A.D."] = "1001-1100"
centval["12th A.D."] = "1101-1200"
centval["twelfth A.D."] = "1101-1200"
centval["thirteenth A.D."] = "1201-1300"
centval["13th A.D."] = "1201-1300"
centval["fourteenth A.D."] = "1301-1400"
centval["14th A.D."] = "1301-1400"
centval["fifteenth A.D."] = "1401-1500"
centval["15th A.D."] = "1401-1500"
centval["sixteenth A.D."] = "1501-1600"
centval["16th A.D."] = "1501-1600"

centval["15th B.C."] = "-1500--1401"
centval["twelfth B.C."] = "-1200--1101"
centval["tenth B.C."] = "-1000--901"
centval["eleventh B.C."] = "-1100--1001"
centval["ninth B.C."] = "-900--801"
centval["8th B.C."] = "-800--701"
centval["eighth B.C."] = "-800--701"
centval["seventh B.C."] = "-700--601"
centval["7th B.C."] = "-700--601"
centval["sixth B.C."] = "-600--501"
centval["6th B.C."] = "-600--501"
centval["5th B.C."] = "-500--401"
centval["fifth B.C."] = "-500--401"
centval["fourth B.C."] = "-400--301"
centval["4th B.C."] = "-400--301"
centval["3rd B.C."] = "-300--201"
centval["third B.C."] = "-300--201"
centval["2nd B.C."] = "-200--101"
centval["second B.C."] = "-200--101"
centval["1st B.C."] = "-100--001"
centval["first B.C."] = "-100--001"
centval["a B.C."] = "-100--001"
centval["the B.C."] = "-100--001"
centval["last B.C."] = "-100--001"
centval["first A.D."] = "001-100"
centval["2nd A.D."] = "101-200"
centval["second A.D."] = "101-200"
centval["3rd A.D."] = "201-300"
centval["third A.D."] = "201-300"
centval["4th A.D."] = "301-400"
centval["fourth A.D."] = "301-400"
centval["fifth A.D."] = "401-500"
centval["5th A.D."] = "401-500"
centval["sixth A.D."] = "501-600"
centval["6th A.D."] = "501-600"
centval["seventh A.D."] = "601-700"
centval["7th A.D."] = "601-700"
centval["eighth A.D."] = "701-800"
centval["8th A.D."] = "701-800"
centval["ninth A.D."] = "801-900"

centval["9th A.D."] = "801-900"
centval["10th A.D."] = "901-1000"
centval["tenth A.D."] = "901-1000"
centval["11th A.D."] = "1001-1100"
centval["eleventh A.D."] = "1001-1100"
centval["12th A.D."] = "1101-1200"
centval["twelfth A.D."] = "1101-1200"
centval["thirteenth A.D."] = "1201-1300"
centval["13th A.D."] = "1201-1300"
centval["fourteenth A.D."] = "1301-1400"
centval["14th A.D."] = "1301-1400"
centval["fifteenth A.D."] = "1401-1500"
centval["15th A.D."] = "1401-1500"
centval["sixteenth A.D."] = "1501-1600"
centval["16th A.D."] = "1501-1600"

centval["1st B.C."] = "-100--001"
centval["first B.C."] = "-100--001"
centval["a B.C."] = "-100--001"
centval["the B.C."] = "-100--001"
centval["last B.C."] = "-100--001"
centval["first A.D."] = "001-100"
centval["2nd A.D."] = "101-200"
centval["second A.D."] = "101-200"
centval["3rd A.D."] = "201-300"
centval["third A.D."] = "201-300"
centval["4th A.D."] = "301-400"
centval["fourth A.D."] = "301-400"
centval["fifth A.D."] = "401-500"
centval["5th A.D."] = "401-500"
centval["sixth A.D."] = "501-600"
centval["6th A.D."] = "501-600"
centval["seventh A.D."] = "601-700"
centval["7th A.D."] = "601-700"
centval["eighth A.D."] = "701-800"
centval["8th A.D."] = "701-800"
centval["ninth A.D."] = "801-900"

centval["9th A.D."] = "801-900"
centval["10th A.D."] = "901-1000"
centval["tenth A.D."] = "901-1000"
centval["11th A.D."] = "1001-1100"
centval["eleventh A.D."] = "1001-1100"
centval["12th A.D."] = "1101-1200"
centval["twelfth A.D."] = "1101-1200"
centval["thirteenth A.D."] = "1201-1300"
centval["13th A.D."] = "1201-1300"
centval["fourteenth A.D."] = "1301-1400"
centval["14th A.D."] = "1301-1400"
centval["fifteenth A.D."] = "1401-1500"
centval["15th A.D."] = "1401-1500"
centval["sixteenth A.D."] = "1501-1600"
centval["16th A.D."] = "1501-1600"



inheader = 1
needspace = 0
entryids = []
badxrefs = {}
for l in f:
#    print(l,end='',file=outf)
 #   continue
    if(inheader):
        if(re.search('</teiHeader>',l)):
            inheader = 0
        print(l,end='',file=outf)
        continue
    l = re.sub('\s*\n',' ',l)
    l = re.sub('^\s+','',l)
    l = re.sub('([,;:])</hi>','</hi>\g<1>',l)
    l = re.sub('\&amp;c','etc',l)
    l = re.sub('\&amp;C','ETC',l)
    l = re.sub('\&amp;\.c','etc',l)
    

    if(1 and re.search('^\s*(<div|<by|<p>|<row|<table|</div>)',l)):
        l = re.sub('^\s*(<div|<by|<p>|<row|<table|</div>)','\n\n\g<1>',l)
    if(re.search('^\s*(<head|<milestone)',l)):
        l = re.sub('^\s*(<head|<milestone)','\n\g<1>',l)
    
    m = re.search('entry" xml:id="([^"]+)',l)
    if(m):
        entryids.append(m[1])
    print(l,end='',file=outf)

f.close()
outf.close()
print('pass 1 done')
f = open('smithgeo-work1.xml')
outf = open('smithgeo-work.xml','w')

places1 = 0
titles1 = 0

newdates = 0
newdates1 = 0
newdates2 = 0
newdates3 = 0

inheader = 1
xrefn = 0
xreffails = 0
altxrefs = {}
altxrefs['aeoliae-insulae-geo'] = 'avernus-lacus-geo'
altxrefs['aeoliae-insulae-geo'] = 'aeoliae-geo'
altxrefs['apenninus-geo'] = 'apenninus-mons-geo'
altxrefs['britannia-geo'] = 'britannicae-insulae-geo'
altxrefs['bosporus-geo'] = 'bosporus-thracius-geo'
altxrefs['carteia-geo'] = 'carteaia-geo'
altxrefs['cantabri-geo'] = 'cantabria-geo'
altxrefs['celtiberi-geo'] = 'celtiberia-geo'
altxrefs['crotona-geo'] = 'croton-geo'
altxrefs['dariorigum-geo'] = 'dairiorigum-geo'
altxrefs['drangae-geo'] = 'drangiana-geo'
altxrefs['gallia-geo'] = 'gallia-transalpina-geo'
altxrefs['heliopolis-geo'] = 'heliopolis-syriae-geo'

altxrefs['heraclea-geo'] = 'heracleia-geo'
altxrefs['laeêtani-geo'] = 'laeaetani-geo'
altxrefs['latini-geo'] = 'latium-geo'
altxrefs['laus-geo'] = 'laus-pompeia-geo'
altxrefs['mandubii-geo'] = 'mandubi-geo'
altxrefs['nabathaei-geo'] = 'nabataei-geo'
altxrefs['oasis-geo'] = 'oases-geo'
altxrefs['plataeae-geo'] = 'plataea-geo02'
altxrefs['arae-philaenorum-geo'] = 'philaeni-geo'
altxrefs['syrtes-geo'] = 'syrtica-regio-geo'
altxrefs['syrtica-geo'] = 'syrtica-regio-geo'
altxrefs['vallum-geo'] = 'vallum-romanum-geo'

for l in f:

    if(inheader):
        if(re.search('</teiHeader>',l)):
            inheader = 0
        print(l,end='',file=outf)
        continue

    l = re.sub('<hi rend="smallcaps">(B\.C\.|A\.D\.)</hi>','\g<1>',l)
    l = re.sub('<hi rend="smallcaps">(B\.C\.|A\.D\.)</hi>','\g<1>',l)
    l = re.sub('<hi rend="smallcaps">(B\.C|A\.D)</hi>\.','\g<1>.',l)
    l = re.sub('<hi rend="smallcaps">(B\.C\.|A\.D\.)(\s+[0-9]+)</hi>','\g<1>\g<2>',l)
    l = re.sub('(<[^>]+)\s+>','\g<1>>',l)
    m = re.search('entry" xml:id="([^"]+)',l)
    if(m):
        curentryid = m[1]
    
    #find in-text cross-references
    
    l = re.sub('<title>([^<]+</title>[,\s]+)(p\.|pp\.|vol\.|[0-9]+)','<xtitle>\g<1>\g<2>',l)
    #l = re.sub('<title>[^<]+</title>[,\s]+(p\.|pp\.|vol\.|[0-9]+)',' ',l)
    
    matchs = '(<title>[A-Z][a-z]+)(,\s+)([A-Z][a-z]+)(,)'
    
    while(re.search(matchs,l)):
        l = re.sub(matchs,'\g<1></title>\g<2><title>\g<3>\g<4>',l)

    l = re.sub('(<title>[A-Z][a-zá]+)(,\s+)([A-Z][a-z]+</title>)','\g<1></title>\g<2><title>\g<3>',l)
    l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3></title>\g<4><title>\g<5>',l)
    l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3>',l)

    l = re.sub('\\b(pl\.\s+)([0-9]+)','<ref type="plate" n="\g<2>">\g<1>\g<2></ref>',l)
    l = re.sub('\\b(fig\.\s+)([0-9]+)','<ref type="figure" n="\g<2>">\g<1>\g<2></ref>',l)
    l = re.sub('\\b(pt\.\s+)([0-9]+)','<ref type="part" n="\g<2>">\g<1>\g<2></ref>',l)
    l = re.sub('(vol\.\s+)([0-9]+)','<ref type="volume" n="\g<2>">\g<1>\g<2></ref>',l)
    matchs = '(vol\.\s+)([ivx]+)'
    
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        volnum = rnums[m[2]]
        l = re.sub(matchs,'<ref type="volume" n="'+str(volnum)+'">\g<1></z>\g<2></ref>',l)
    l = re.sub('</z>','',l)
        
    matchs = '<title>([^<]+)</title>'
    while(re.search(matchs,l)):
        curdel = ''
        m = re.search(matchs,l)
        curword = m[1]
        matchword = re.sub('\.','',curword)
        if(matchword in placelist):
            places1 = places1 + 1
            #print('match',places1,curword)
            l = re.sub(matchs,'<placeName type="modern" rend="ital">\g<1></placeName>',l,1)
            l = re.sub('(\.)(</placeName>)','\g<2>\g<1>',l)
            continue
        titles1 = titles1 + 1
        l = re.sub(matchs,'<xtitle>\g<1></title>',l,1)
    l = re.sub('<xtitle>','<title>',l)
    l = re.sub('(the\s+modern)\s+<title>([^<]+)</title>','\g<1><placeName type="modern" rend="ital">\g<2></placeName>',l)

    while(re.search('(<quote[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</quote>)',l)):
        m = re.search('(<quote[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</quote>)',l)
        betas = m[3]
        unis = r.beta_code(betas)
        #print(unis)
        l = re.sub('(<quote[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</quote>)','\g<1>'+'xml:lang="grc"'+'\g<2>'+unis+'\g<4>',l,1)
    l = re.sub('λ>','l>',l)
    l = re.sub('σπεακερ>','speaker>',l)
    l = re.sub('σπ>','sp>',l)

    l = re.sub('quote\s+xml:lang="greek"','quote xml:lang="grc"',l)
    while(re.search('(<label[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</label>)',l)):
        m = re.search('(<label[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</label>)',l)
        betas = m[3]
        unis = r.beta_code(betas)
        #print(unis)
        l = re.sub('(<label[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</label>)','\g<1>'+'xml:lang="grc"'+'\g<2>'+unis+'\g<4>',l,1)
    
    while(re.search('(<foreign[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</foreign>)',l)):
        m = re.search('(<foreign[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</foreign>)',l)
        betas = m[3]
        unis = r.beta_code(betas)
        #print(unis)
        l = re.sub('(<foreign[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</foreign>)','\g<1>'+'xml:lang="grc"'+'\g<2>'+unis+'\g<4>',l,1)

    m = re.search('<milestone unit="volume" n="([0-9]+)"',l)
    l,hits = re.subn('(\s+|\()(A\.\s*D\.)\s+([0-9]+)','\g<1><date when-custom="\g<3>">\g<2> \g<3></date>',l)
    newdates1 = newdates1 + hits
    l,hits = re.subn('(\s+|\()(B\.\s*C\.)\s+([0-9]+)','\g<1><date when-custom="-\g<3>">\g<2> \g<3></date>',l)
    newdates1 = newdates1 + hits
    l,hits = re.subn('([0-9]+|[0-9]+\-[0-9]+)\s+(B\.\s*C\.)','<date when-custom="-\g<1>">\g<1> \g<2></date>',l)
    newdates1 = newdates1 + hits
    l,hits = re.subn('([0-9]+)([,\s]*)(A\.\s*D\.)','<date when-custom="\g<1>">\g<1>\g<2>\g<3></date>',l)
    newdates1 = newdates1 + hits
   

    
    i = 0 
    matchs = '<date when-custom="([0-9]+|\-[0-9]+)">([^<]+</date>)(\s+and\s+|\s+or\s+|\s+to\s+|\s+till\s+|,\s+)([0-9]+|\-[0-9]+)'
    m = re.search(matchs,l)
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        newdates = newdates + 1
        date1 = m[1]
        linkword = m[3]
        date2 = m[4]
        if(re.search('^\-',date1)):
            date2 = '-' + date2
            #print('date2 now',date1,date2,l)
        i = i + 1
        if(i> 100):
            print('outofcontrol1',l)
            break
        if(0 and int(date2) < int(date1)):
            print('newdate',curentryid,curvolume,curpage,date1,linkword,date2,l,end='')
        l = re.sub(matchs,'<date when-custom="\g<1>">\g<2>\g<3><date when-custom="\g<4>">\g<4></date>',l,1)
        
    while(re.search('([^"]+">[^<]+</date>)\s*-\s*([0-9]+)',l)):
        m = re.search('([^"]+">[^<]+</date>)\s*-\s*([0-9]+)',l)
        #print('m1',m[1])
        if(m[1][0] == '-'):
            l,hits = re.subn('([^"]+">[^<]+</date>)\s*-\s*([0-9]+)','\g<1>-<date when-custom="-\g<2>">\g<2></date>',l)
        else:
            l,hits = re.subn('([^"]+">[^<]+</date>)\s*-\s*([0-9]+)','\g<1>-<date when-custom="\g<2>">\g<2></date>',l)

    #l,hits = re.subn('(</date>)\s*-\s*([0-9]+)','\g<1>-<date when-custom="'+date2+'">\g<2></date>',l)
    newdates2 = newdates2 + hits
    

    workl = l
    matchs = '<date when-custom="([0-9\-]+)">([^<]+)</date>-<date when-custom="([0-9\-]+)">'
    while(re.search(matchs,workl)):
        m = re.search(matchs,workl)
        date1 = m[1]
        date2 = m[3]
        if(not len(date1) == len(date2) and int(date1) > int(date2)):
            datemask = re.sub('(.)','.',date2) + '$'
            half1 = re.sub(datemask,'',date1)
            newdate2 = half1 + date2
            if(0 and int(newdate2) < int(date1)):
                print('unmatched',date1,date2,newdate2)
            l = re.sub('when-custom="' + date2+ '"','when-custom="' + newdate2 + '"',l)
        workl = re.sub(matchs,'',workl,1)

    matchs = '(January|February|March|April|May|June|July|August|September|October|November|December)([,\s]+)([0-9]+)'
    l = re.sub(matchs,'\g<1>\g<2><date when-custom="\g<3>">\g<3></date>',l)


    if(re.search('<p>',l)):
        l = re.sub('([A-Z][a-z][a-z]\.)','<abbr>\g<1></abbr>',l)
        l = re.sub('<abbr>'+shortpat+'\.</abbr>','\g<1>.',l)
        while(re.search('(="[^"]*|<bibl[^>]*>[^<]*|<title[^>]*>[^<]*)<[/]*abbr>',l)):
            l = re.sub('(="[^"]*|<bibl[^>]*>[^<]*|<title[^>]*>[^<]*)<[/]*abbr>','\g<1>',l)
        if(0 and re.search('It is usually stated on the authority of Ephorus',l)):
            print('work',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*\s+[A-Za-z\']+[,\s]|[A-Z][a-z]*\s+<[a-zA-Z]+)','\g<1>\n<s n="r01"/>\g<2>',l)
        l,hits = re.subn('(\)\.|\.\)|\.</hi>\)|\.</hi>|\.</foreign>\))\s+([A-Z])','\g<1>\n<s n="r2"/>\g<2>',l)
        l,hits = re.subn('(</date>\.)\s+([A-Z])','\g<1>\n<s n="r3"/>\g<2>',l)
        l,hits = re.subn('(\]\.|\.\)])\s+([A-Z])','\g<1>\n<s n="r4"/>\g<2>',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*,\s+[A-Za-z]+[,\s])','\g<1>\n<s n="r5"/>\g<2>',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*\s+\()','\g<1>\n<s n="r6"/>\g<2>',l)
        l,hits = re.subn('(\.</hi>\])\s+([A-Z])','\g<1>\n<s n="r7"/>\g<2>',l)
        l,hits = re.subn('(\.)\s+(In\s+<date)','\g<1>\n<s n="r8"/>\g<2>',l)
        l,hits = re.subn('(\.</foreign>)\s+([A-Z])','\g<1>\n<s n="r9"/>\g<2>',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*\s+[A-Za-z]+[,\s]|[A-Z][a-z]*\s+<title)','\g<1>\n<s n="r10"/>\g<2>',l)
        l,hits = re.subn('(</ref>\]|</bibl>\))\s+([A-Z])','\g<1>\n<s n="r11"/>\g<2>',l)
        l,hits = re.subn('(\.</hi>)\s+([A-Z][a-z]+\s)','\g<1>\n<s n="r12"/>\g<2>',l)

    olymppat = '([0-9]+)([a-z]+\s+Olympiad)'
    while(re.search(olymppat,l)):
        m = re.search(olymppat,l)
        ol = int(m[1])
        startyear = -776 + (4*(ol-1))
        endyear = startyear + 3
        yearrange = str(startyear) + '-' + str(endyear)
        l = re.sub(olymppat,'<date when-custom="'+yearrange+'">\g<1><z/>\g<2></date>',l,1)
    l = re.sub('<z/>','',l)
    
    
    matchs = '([a-zA-Z0-9]+)\s+(century)\s+([AB]\.\s*[DC]\.|after\s+Christ|before Christ|of\s+our\s+[a]*era|of\s+the\s+Christian\s+[a]*era)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        if(m[3] == 'after Christ' or m[3] == 'of our era' or m[3] == 'of our aera' or  m[3] == 'of the Christian era' or  m[3] == 'of the Christian aera' ):
            era = 'A.D.'
        elif(m[3] == 'before Christ'):
            era = 'B.C.'
        else:
            era = m[3]
        curkey = m[1] + ' ' + era
        curkey = re.sub('\.\s+','.',curkey)
        if(not curkey in centval):
            print('missingcentval',curkey,l)
            curval = 'noval'
        else:
            curval = centval[curkey]
        l = re.sub(matchs,'<date when-custom="'+curval+'">\g<1> \g<2> <z/>\g<3></date>',l,1)
    l = re.sub('<z/>','',l)
    
    l,hits = re.subn('([0-9]+)(\s+to\s+<date when-custom="-)','<date when-custom="-\g<1>">\g<1></date>\g<2>',l)
    newdates3 = newdates3 + hits
    
    matchs = '(<hi rend="smallcaps">)([^<,]+)(\s*[;:,]\s+)([A-Z]+)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        xrefn = xrefn + 1
        key1 = m[2]
        key2 = m[4]

        #print(curentryid,xrefn,key1,key2)
        l = re.sub(matchs,'\g<1>\g<2></hi>\g<3><hi rend="smallcaps">\g<4>',l,1)
        
        continue
        
        
    matchs = '(<hi rend="smallcaps">)([^<]+)</hi>' 
    if(re.search(matchs,l)):
        m = re.search(matchs,l)
        newxref = m[2]
        newxref = re.sub('\.$','',newxref)
        trykey = newxref.lower() + '-geo'
        trykey = re.sub('\.','',trykey)
        trykey = re.sub('\s+','-',trykey)
        if(trykey in altxrefs):
            trykey = altxrefs[trykey]
        
        if(trykey in entryids):
            res = 'hit'
            l = re.sub(matchs,'<ref target="'+trykey+'" n="U">\g<2></ref>',l,1)

        else:
            res = 'fail'
            xreffails = xreffails + 1
            l = re.sub(matchs,'<hix rend="smallcaps">\g<2></hi>',l,1)
            if(newxref in badxrefs):
                badxrefs[newxref] = badxrefs[newxref] + 1
            else:
                badxrefs[newxref] = 1
        #print(xreffails,curentryid,trykey,newxref,res)

    l = re.sub('<hix ','<hi ',l)
    
    l = re.sub('(Orelli|Orell\.)([,\s]+|[,\s]+[Nn]o[s]*\.\s+)([0-9]+)','<bibl n="Orelli Inscr \g<3>">\g<1>\g<2>\g<3></bibl>',l)
    
    matchs = '(Orell[\.i][,\s+]+)<title>([^<]+)</title>(\s+|[,\s]+[Nn]o[s]*\.\s+)([0-9][0-9\-]*)'
    l = re.sub(matchs,'<bibl n="Orelli Inscr \g<4>">\g<1>\g<2>\g<3>\g<4></bibl>',l)
    
    matchs = '(<bibl n="Orelli Inscr\s+)([^>]+>[^<]+</bibl>)(,\s+)([0-9][0-9\-]*)'
    while(re.search(matchs,l)):
        l = re.sub(matchs,'\g<1>\g<2>\g<3>\g<1>\g<4>">\g<4></bibl>',l,1)
        
    l = re.sub('(No[s]*\.)(\s+[^< ]+</bibl>)','\g<1></z>\g<2>',l)
    
    matchs = '(No[s]*\.)([,\s]+)([0-9]+[a-z]*)'
    
    l = re.sub(matchs,'<ref type="number" n="\g<3>">\g<1></z>\g<2>\g<3></ref>',l)
     
    l = re.sub('</z>','',l)
    
    matchs = '(<ref type="number"[^>]+>[^<]+</ref>[,\s\-]+)([0-9]+[a-z]*)'
    while(re.search(matchs,l)):
        l = re.sub(matchs,'\g<1><ref type="number" n="\g<2>">\g<2></ref>',l,1)
    
    
    
    l = re.sub('(<bibl n="[^"]+ p)\.','\g<1>age',l)
    l = re.sub('(<bibl n="[^"]+ p)p\.','\g<1>ages',l)
    matchs = '\\b(p\.|pp\.)\s+([0-9][0-9\-]*[a-f]*)'
    l = re.sub(matchs,'<ref type="page" n="\g<2>">\g<1> \g<2></ref>',l)
    
    matchs = '(<ref type="page"[^>]+>[^<]+</ref>[,\s]+)([0-9][0-9\-]*[a-f]*)'
    while(re.search(matchs,l)):
        l = re.sub(matchs,'\g<1><ref type="page" n="\g<2>">\g<2></ref>',l)
    
    
    matchs = '([0-9]+,[0-9][0-9,]+[0-9]|[0-9]+|[0-9]+\s+[0-9]+/[0-9]+)\s+([A-Z][a-z]+|geog[\.a-z]+|heroic|new|of\s+the[a-z]*|sq\.|square|select)\s+([a-z\-]+)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        number = fract2dec(m[1])
        word1 = m[2]
        word2 = m[3]
        if(word2 in countwords):
            l = re.sub(matchs,'<measure quantity="'+number+'" n="\g<2> \g<3>">\g<1> \g<2> \g<3></measure>',l,1)
        l = re.sub(matchs,'\g<1></z> \g<2> \g<3>',l)
    
    l = re.sub('</z>','',l)
    
    matchs = '([0-9]+,[0-9][0-9,]+[0-9]|[0-9]+|[0-9]+\s+[0-9]+/[0-9]+)\s+(M\.\s*P\.)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        number = fract2dec(m[1])
        word1 = re.sub(' ','',m[2])

        l = re.sub(matchs,'<measure quantity="'+number+'" n="milia_passuum">\g<1></z> \g<2></measure>',l,1)

    
    matchs = '([0-9]+,[0-9][0-9,]+[0-9]|[0-9]+)\s+(vols\.|vol\.)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        number = re.sub(',','',m[1])
        word1 = re.sub(' ','',m[2])

        l = re.sub(matchs,'<measure quantity="'+number+'" n="volumes">\g<1></z> \g<2></measure>',l,1)
        
    matchs = '([0-9]+,[0-9][0-9,]+[0-9]|[0-9]+|[0-9]+\s+[0-9]+/[0-9]+)\s+([a-z\-]+|[A-Z][a-z]+s\\b)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        number = fract2dec(m[1])
        word1 = m[2]

        if(word1 in countwords or re.search('[A-Z].+s$',word1)):
            l = re.sub(matchs,'<measure quantity="'+number+'" n="\g<2>">\g<1> \g<2></measure>',l,1)
        l = re.sub(matchs,'\g<1></z> \g<2>',l,1)
    
    l = re.sub('</z>','',l)
 
    matchs = '\\b([Ii]n\s+|year\s+)([0-9]+\.[0-9]+\.[0-9]+|[0-9]+\.[0-9]+)'

    l = re.sub(matchs,'\g<1><ref>\g<2></ref>',l)
    
    
    l = re.sub('(4to\.|4to)','<measure n="quarto">\g<1></measure>',l)
    l = re.sub('(8vo\.|8vo)','<measure n="octavo">\g<1></measure>',l)

    matchs = '([0-9]+)(\s+or\s+|\s+and\s+|\s+to\s+)<measure quantity="([^"]+)" n="([^"]+)">'

    l = re.sub(matchs,'<measure quantity="\g<1>" n="\g<4>">\g<1></measure>\g<2><measure quantity="\g<3>" n="\g<4>">',l)

    matchs = '([0-9]+|[0-9]+\s+[0-9]+/[0-9]+)°\s+([0-9]+|[0-9]+\s+[0-9]+/[0-9]+)′\s+([0-9]+|[0-9]+\s+[0-9]+/[0-9]+)″'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        degrees = fract2dec(m[1])
        minutes = fract2dec(m[2])
        seconds = fract2dec(m[3])
        if(re.search('/',degrees)):
            print('fraction',curentryid,m[1],m[2])
        l = re.sub(matchs,'<measure type="degree" quantity="'+degrees+'">\g<1></z>°</measure> <measure type="minute" quantity="'+minutes+'">\g<2></z>′</measure> <measure type="second" quantity="'+seconds+'">\g<3></z>″</measure>',l,1)

    matchs = '([0-9]+|[0-9]+\s+[0-9]+/[0-9]+)°\s+([0-9]+)′'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        degrees = fract2dec(m[1])
        minutes = fract2dec(m[2])
        l = re.sub(matchs,'<measure type="degree" quantity="'+degrees+'">\g<1></z>°</measure> <measure type="minute" quantity="'+minutes+'">\g<2></z>′</measure>',l,1)
           

    matchs = '([0-9]+|[0-9]+\s+[0-9]+/[0-9]+)°'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        degrees = fract2dec(m[1])
            
          #print(curentryid,m[1],m[2])
        l = re.sub(matchs,'<measure type="degree" quantity="'+degrees+'">\g<1></z>°</measure>',l,1)
          
    l = re.sub('</z>','',l)      

    
    m = re.search('<bibl n="([A-Z][a-z]+)',l)
    if(m):
        if(not m[1] in lastbib):
            lastbib.append( m[1])
        
    m = re.search('<date when-custom="([^"]+)"',l)
    if(m):
            lastdate = m[1]
            

    
    matchs = '\\b([Ii]n\s+)([0-9]+\.[0-9]+\.[0-9]+|[0-9]+\.[0-9]+)'

    l = re.sub(matchs,'\g<1><ref>\g<2></ref>',l)
    

    
    m = re.search('entry" xml:id="([^"]+)',l)
    if(m):
        curentryid = m[1]
        lastdate = 'nolast'
        lastbib = []
    
    matchs = '\\b([a-zA-Z]+)\s+([a-zA-Z]+)\s+\(([0-9]+)\)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
    
        if(m and int(m[3]) > 9 and int(m[3]) < 1000 and not m[2] in notyears):
            j = j + 1
            if(re.search('^-',lastdate) or 'Liv' in lastbib or 'Cic' in lastbib or 'Thuc' in lastbib or 'Dionys' in lastbib):
                newdate = '-' + m[3]
            else:
                newdate = m[3]
            #print(j,'paren',curentryid,lastdate,'Cic' in lastbib,lastbib,m[1],m[2],m[3],newdate)
            l = re.sub(matchs,'\g<1> \g<2> (<date when-custom="'+newdate+'">\g<3></date>)',l,1)
        else:
            l = re.sub(matchs,'\g<1> \g<2> (<ref>\g<3></ref>)',l,1)
    
    matchs = '\\b([Ii]n)\s([0-9]+)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)            
        newdate = m[2]
        if(re.search('^-',lastdate) or  'Plb' in lastbib or 'Liv' in lastbib or 'Cic' in lastbib):
            if(int(m[2])< 900):
                newdate = '-' + m[2]
            else:
                newdate = m[2]
        else:
            newdate = m[2]
        if(len(newdate) == 1):
            shows = l
        else:
            shows = ''
        i = i + 1
        if(lastdate == 'nolast' and not lastbib == 'nobib' and int(newdate)  < 1000):
            print(i,curentryid,'newdate',lastdate,lastbib,newdate,shows)
        l =re.sub(matchs,'\g<1> <date when-custom="'+newdate+'">\g<2></date>',l,1)
        
    
    print(l,end='',file=outf)
    

f.close()
outf.close()

#for foo in sorted(badxrefs,key=badxrefs.get,reverse=True):
#    print(foo,badxrefs[foo])
print('pass 2 done',newdates1,newdates2,'dates3',newdates3,places1,titles1,'xrefs',xrefn,xreffails)
# Out:
# pass 1 done
# pass 2 done 4977 192 dates3 2 21453 10484 xrefs 1135 2045

# %%
titles = {}
titlelen = {}

ethnics = {}
f = open('ethnics-list.txt')
for l in f:
    l = re.sub('^[\s0-9]+','',l)
    l = re.sub('\n','',l)
    ethnics[l] = 1
f.close()

print('ethnics done')

places = []
f2 = open('place-excepts.txt')
for l in f2:
    l = re.sub('^[\s0-9]+','',l)
    l = re.sub('\n','',l)
    if(not re.search('[A-Z]',l)):
        continue
    places.append(re.sub('\n','',l))

f2.close()

print('places done')

f = open('smithgeo-work.xml')

skipit = 0
hits = 0
for l in f:
    #if(not re.search('<p>',l)):
    #    continue

    l = re.sub('(<title>[A-Z][a-z]+),\s+([A-Z][a-z]+</title>)','\g<1></title>, <title>\g<2>',l)
    l = re.sub('<title>[^<]+</title>[,\s]+(p\.|pp\.|vol\.|[0-9]+)',' ',l)
    matchs = '<title>([A-Z][a-z][a-z][a-z][^<]+)</title>'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        curabb = m[1]
#        if(curabb in ethnics):
 #           continue
        if(curabb in places or curabb in ethnics):
            skipit = skipit + 1
            l = re.sub(matchs,'',l,1)
            continue
        hits = hits + 1
        if(curabb in titles):
            titles[curabb] = titles[curabb] + 1
        else:
            titles[curabb] = 1
        l = re.sub(matchs,'',l,1)
    

f.close()
print(hits,skipit)
i = 4

outf = open('placestmp.txt','w')
for foo in titles:
    titlelen[foo] = len(foo)
    
#for foo in sorted(titles,key=titles.get,reverse=True):
for foo in sorted(titlelen,key=titlelen.get):

    if(foo in places):
        continue
    if(len(foo) > 28):
        continue
    if(re.search('(Untersuch|Settlements|Proceeding|Wört|Vorträg|Hebrew|Cyclop|Land of|Sons of|Rocky A|Ethnog|Penny|Ruin|Coins|Wallfahrt|Correspon|Genius|Museo|Archiv|Periplus|Notice|Tableaux|unter den Römern|Explor|Scient|Geschic|Ricerch|Zeitsch|Museum|Account|Handbuch|Economie|Atti|Architett|Acta|Years|Onomast|Comment|Liber|Histor|Mittel Italien|Deuteronomy|Nehem|Wanderu|Tour|Carta\s|Encycl|Descriz|Revu|^Southern$|^Northern$|Annali|Chronogr|Erdkunde|Sitten|Lexic|Rapport|Rosett|Bericht|Geolog|Monum|Medieval|Archaeol|Transact|Handboo|Architect|Greece\s+under|Notes|\s+et\s+|Guid|\s+und\s+|Vita|Symboli|Bibl\.|Forschung|Italian-Greek|geschicht|Dialekt|antica Città|Antich|Observa|Remembrancer|Ausland|Memori|Memoir|Vindic|Misc|Trav|Remains|\s+u\.|Hadrian|Comm|Antiq|Mytholog|Recherch|Pelasger|Journ|Topogr|Topograf|Geogr|Navig|Life of|Dialect|Annal|Transl|Discors|Voyage|Hist\.|Histoir|Lecture|Analys|Descript|\s+and\s+|Beschreibung|Itiner|Schrift|Antichit|Research|Diction|Discover|Reise|Viagg|Travel|Atlas)',foo)):
        continue
    if(re.search('(Acts|Afrique Ancienne|Arabs of the Arabs|philolog|Apocalypse|Corograf|Denkmäl|Della |Dell\' |Denkmal|Etymol|Exped|Exercitat|Explana|Fundgrub|Isaiah|Iscriz|Itin|Numism|Odes |Philolog|Statisti|Statues of|Uber |Urkund|Wanderzungen|Zeitung)',foo)):
        continue
    if(re.search('(Fasti|Lettres|Restes|Statist|Discourse|Book|Onom\.|Epistle|Stadiasm|Corrispond|Relations|Chronolog|Colonies|Tribes|survey|Chariots|commerce|Karte|Theolog|Review|Revue|Revist|Beiträg|Theophanes|Ausonian|Cynegetice|Disputat|Dorian|Italian|Judges|Aegyptiaca|Artemid|Asians|authorit|Bacchic|Basis |British|Decline|Dintorni|Dissert|Doctr\.|Etrusker|Fragment|Georgius|Joshua|Legionary|Peloponnesiaca|Preface|relations|Specimen|Tshina)',foo)):
        continue
    if(re.search('(Kings|Diccion|Verr\.|Olynth\.|Iliad|Corpus|Appendix|Chaldäer|Gall. Duo|Descr\.|Relazion|the Huns|Cosmograph|Bullettino|Arts|Battles|March from|Letters|illustrata|Excerpta|Gospels|Pianta della|Religion|Dial\.|Peripl\.|Urbewohner|Studie|Carte |Alterthums|Linguae|Chronica|Diss.|Nations|Cenotaphia|Saxons in England|Peintures|Prometheus|Chronicon|Question|Ortsnamen|Illustraz|Survey|Econom|Visit|Epist\.|Dict\.|Paulae|Fast. Amitern|Childe Harold|Spec. Rei|Meteorologics|Realwörterbuch|Geog\.|Epitaph|Ancient|Anecdot|Ascent of|Biograph|Bishop|Delizie|encyclop|Europaïsche|Gesch\.|Greeks in|Inscrift|Magazine|Marmora|Mythical|Period|Pheidias|Remark|Skizze|Stadias\.|Storia|\s+tracts|officers)',foo)):
        continue
    if(re.search('(Alex|Amor|Anab|Anal|Anns|Aurel|Caes|Claud|Deut|Epit|Erdk|Handb|Hymn|Idyll|Insc|Ital|Judg|Mith|Orat|Pers|Peut|Propempt|Prov|Pyth|Samn|Tech|Theb|Them)\.',foo)):
        continue
    if(re.search('(Anecd|Annot|Anton|Apol|Chron|Epod|Fragm|Gramm|Inscr|Mithr|Numid|Opusc|Paneg|Praef|Protr|Sever|Stud|Theag|Thes)\.',foo)):
        continue
    if(re.search('(Aegin|Agath|Archit|Beschr|Crass|Danub|Dionys|Einleit|Excerpt|Exod|Ezek|Germ|Gloss|Inset|Josh|Oeconom|Orat|Panegyr|Pesc|Phaed|Phil|Strab|Suppl|Vitell)\.',foo)):
        continue
    if(re.search('(Astrolog|Controv|Inscript)\.',foo)):
        continue
    
    i = i + 1
    if( re.search('\.\s+',foo) and not re.search('(S\.|St\.)',foo)):
        continue
    foo = re.sub('\.$','',foo)
    print(foo,file=outf)
    #print(i,titlelen[foo],titles[foo],foo,file=outf)
        
        
outf.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4daac714ae16> in <module>
#       5 f = open('ethnics-list.txt')
#       6 for l in f:
# ----> 7     l = re.sub('^[\s0-9]+','',l)
#       8     l = re.sub('\n','',l)
#       9     ethnics[l] = 1
#
# NameError: name 're' is not defined

# %%
'Loire' in placelist
# Out:
# True

# %%
l = '<title>Valmontone, Zagarolo</title>, and <title>Lugnano.</title>'

l = re.sub('(<title>[A-Z][a-zá]+)(,\s+)([A-Z][a-z]+</title>)','\g<1></title>\g<2><title>\g<3>',l)
l
l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3></title>\g<4><title>\g<5>',l)
l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3>',l)
l
# Out:
# '<title>Valmontone</title>, <title>Zagarolo</title>, and <title>Lugnano.</title>'

# %%
l = 'fall of 1983 feet in a direct co'

    
matchs = '([0-9]+,[0-9][0-9,]+[0-9]|[0-9]+)\s+([a-z\-]+)'
while(re.search(matchs,l)):
        m = re.search(matchs,l)
        number = re.sub(',','',m[1])
        word1 = m[2]
        if(word1 in countwords):
            l = re.sub(matchs,'<measure quantity="'+number+'" n="\g<2>">\g<1> \g<2></measure>',l,1)
        l = re.sub(matchs,'\g<1></z> \g<2>',l)

# %%
l = ' Micali, pl. 7, 8; and by Abek'
matchs = '\\b(pl\.)'
m = re.search(matchs,l)
if(m):
    print('hit')
# Out:
# hit

# %%
print(centval["13th B.C."])
