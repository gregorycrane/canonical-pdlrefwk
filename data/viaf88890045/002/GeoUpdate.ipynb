# %%
#https://en.wikisource.org/wiki/Page:Dictionary_of_Greek_and_Roman_Geography_Volume_I_Part_1.djvu/502

import re

f2 = open('place-excepts.txt')
placelist = []
for l in f2:
    l = re.sub('^[\s0-9]+','',l)
    if(not re.search('[a-z]',l)):
        continue
    placelist.append(re.sub('\n','',l))
f2.close()


f = open("viaf88890045.002.xml","r")
outf = open('smithgeo-work1.xml','w')
import re
from cltk.corpus.greek.beta_to_unicode import Replacer

r = Replacer()


shortnames = ['Cos','Cato','Hera','Jew','Jews','Livy','Milo','Num','Otho','Ovid','Piso','Pius','Way','Ways','West','Zeno','Zeus']
shortpat = '('+ '|'.join(shortnames) + ')'

centval = {}
centval["15th B.C."] = "-1500-1401"
centval["twelfth B.C."] = "-1200-1101"
centval["tenth B.C."] = "-1000-901"
centval["eleventh B.C."] = "-1100-1001"
centval["ninth B.C."] = "-900-801"
centval["8th B.C."] = "-800-701"
centval["eighth B.C."] = "-800-701"
centval["seventh B.C."] = "-700-601"
centval["7th B.C."] = "-700-601"
centval["sixth B.C."] = "-600-501"
centval["6th B.C."] = "-600-501"
centval["5th B.C."] = "-500-401"
centval["fifth B.C."] = "-500-401"
centval["fourth B.C."] = "-100-101"
centval["4th B.C."] = "-400-301"
centval["3rd B.C."] = "-300-201"
centval["third B.C."] = "-300-201"
centval["second B.C."] = "-200-101"
centval["1st B.C."] = "-100-001"
centval["first B.C."] = "-100-001"
centval["a B.C."] = "-100-001"
centval["the B.C."] = "-100-001"
centval["last B.C."] = "-100-001"
centval["first A.D."] = "001-100"
centval["2nd A.D."] = "101-200"
centval["second A.D."] = "101-200"
centval["3rd A.D."] = "201-300"
centval["third A.D."] = "201-300"
centval["4th A.D."] = "301-400"
centval["fourth A.D."] = "301-400"
centval["fifth A.D."] = "401-500"
centval["5th A.D."] = "401-500"
centval["sixth A.D."] = "501-600"
centval["6th A.D."] = "501-600"
centval["seventh A.D."] = "601-700"
centval["7th A.D."] = "601-700"
centval["eighth A.D."] = "701-800"
centval["8th A.D."] = "701-800"
centval["ninth A.D."] = "801-900"

centval["9th A.D."] = "801-900"
centval["10th A.D."] = "901-1000"
centval["tenth A.D."] = "901-1000"
centval["eleventh A.D."] = "1001-1100"
centval["12th A.D."] = "1101-1200"
centval["twelfth A.D."] = "1101-1200"
centval["thirteenth A.D."] = "1201-1300"
centval["13th A.D."] = "1201-1300"
centval["fourteenth A.D."] = "1301-1400"
centval["14th A.D."] = "1301-1400"
centval["fifteenth A.D."] = "1401-1500"
centval["15th A.D."] = "1401-1500"
centval["sixteenth A.D."] = "1501-1600"
centval["16th A.D."] = "1501-1600"

inheader = 1
needspace = 0
entryids = []
for l in f:
#    print(l,end='',file=outf)
 #   continue
    if(inheader):
        if(re.search('</teiHeader>',l)):
            inheader = 0
        print(l,end='',file=outf)
        continue
    l = re.sub('\s*\n',' ',l)
    l = re.sub('^\s+','',l)
    l = re.sub('([,;:])</hi>','</hi>\g<1>',l)
    l = re.sub('\&amp;c','etc',l)
    l = re.sub('\&amp;C','ETC',l)
    l = re.sub('\&amp;\.c','etc',l)
    

    if(1 and re.search('^\s*(<div|<by|<p>|<row|<table|</div>)',l)):
        l = re.sub('^\s*(<div|<by|<p>|<row|<table|</div>)','\n\n\g<1>',l)
    if(re.search('^\s*(<head|<milestone)',l)):
        l = re.sub('^\s*(<head|<milestone)','\n\g<1>',l)
    
    m = re.search('entry" xml:id="([^"]+)',l)
    if(m):
        entryids.append(m[1])
    print(l,end='',file=outf)

f.close()
outf.close()
print('pass 1 done')
f = open('smithgeo-work1.xml')
outf = open('smithgeo-work.xml','w')

places1 = 0
titles1 = 0

newdates1 = 0
newdates2 = 0

inheader = 1
xrefn = 0
xreffails = 0
for l in f:

    if(inheader):
        if(re.search('</teiHeader>',l)):
            inheader = 0
        print(l,end='',file=outf)
        continue

    l = re.sub('(<[^>]+)\s+>','\g<1>>',l)
    m = re.search('entry" xml:id="([^"]+)',l)
    if(m):
        curentryid = m[1]
    
    #find in-text cross-references
    
    l = re.sub('<title>([^<]+</title>[,\s]+)(p\.|pp\.|vol\.|[0-9]+)','<xtitle>\g<1>\g<2>',l)
    #l = re.sub('<title>[^<]+</title>[,\s]+(p\.|pp\.|vol\.|[0-9]+)',' ',l)
    
    matchs = '(<title>[A-Z][a-z]+)(,\s+)([A-Z][a-z]+)(,)'
    
    while(re.search(matchs,l)):
        l = re.sub(matchs,'\g<1></title>\g<2><title>\g<3>\g<4>',l)

    l = re.sub('(<title>[A-Z][a-zá]+)(,\s+)([A-Z][a-z]+</title>)','\g<1></title>\g<2><title>\g<3>',l)
    l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3></title>\g<4><title>\g<5>',l)
    l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3>',l)

        
    matchs = '<title>([^<]+)</title>'
    while(re.search(matchs,l)):
        curdel = ''
        m = re.search(matchs,l)
        curword = m[1]
        matchword = re.sub('\.','',curword)
        if(matchword in placelist):
            places1 = places1 + 1
            #print('match',places1,curword)
            l = re.sub(matchs,'<placeName type="modern" rend="ital">\g<1></placeName>',l,1)
            l = re.sub('(\.)(</placeName>)','\g<2>\g<1>',l)
            continue
        titles1 = titles1 + 1
        l = re.sub(matchs,'<xtitle>\g<1></title>',l,1)
    l = re.sub('<xtitle>','<title>',l)
    l = re.sub('(the\s+modern)\s+<title>([^<]+)</title>','\g<1><placeName type="modern" rend="ital">\g<2></placeName>',l)

    while(re.search('(<quote[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</quote>)',l)):
        m = re.search('(<quote[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</quote>)',l)
        betas = m[3]
        unis = r.beta_code(betas)
        #print(unis)
        l = re.sub('(<quote[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</quote>)','\g<1>'+'xml:lang="grc"'+'\g<2>'+unis+'\g<4>',l,1)
    l = re.sub('λ>','l>',l)
    l = re.sub('σπεακερ>','speaker>',l)
    l = re.sub('σπ>','sp>',l)

    l = re.sub('quote\s+xml:lang="greek"','quote xml:lang="grc"',l)
    while(re.search('(<label[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</label>)',l)):
        m = re.search('(<label[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</label>)',l)
        betas = m[3]
        unis = r.beta_code(betas)
        #print(unis)
        l = re.sub('(<label[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</label>)','\g<1>'+'xml:lang="grc"'+'\g<2>'+unis+'\g<4>',l,1)
    
    while(re.search('(<foreign[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</foreign>)',l)):
        m = re.search('(<foreign[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</foreign>)',l)
        betas = m[3]
        unis = r.beta_code(betas)
        #print(unis)
        l = re.sub('(<foreign[^>]+)xml:lang="greek"([^>]*>)([^<]+)(</foreign>)','\g<1>'+'xml:lang="grc"'+'\g<2>'+unis+'\g<4>',l,1)

    m = re.search('<milestone unit="volume" n="([0-9]+)"',l)
    l,hits = re.subn('(\s+|\()(A\.\s*D\.)\s+([0-9]+)','\g<1><date when-custom="\g<3>">\g<2> \g<3></date>',l)
    newdates1 = newdates1 + hits
    l,hits = re.subn('(\s+|\()(B\.\s*C\.)\s+([0-9]+)','\g<1><date when-custom="-\g<3>">\g<2> \g<3></date>',l)
    newdates1 = newdates1 + hits
    l,hits = re.subn('([0-9])\s+(B\.\s*C\.)','<date when-custom="-\g<1>">\g<1> \g<2></date>',l)
    newdates1 = newdates1 + hits
    

    
    i = 0 
    m = re.search('<date when-custom="([0-9]+|\-[0-9]+)">([^<]+</date>)(\s+and\s+|\s+or\s+|\s+to\s+|,\s+)([0-9]+|\-[0-9]+)',l)
    while(re.search('<date when-custom="([0-9]+|\-[0-9]+)">([^<]+</date>)(\s+and\s+|\s+or\s+|\s+to\s+|,\s+)([0-9]+|\-[0-9]+)',l)):
        m = re.search('<date when-custom="([0-9]+|\-[0-9]+)">([^<]+</date>)(\s+and\s+|\s+or\s+|\s+to\s+|,\s+)([0-9]+|\-[0-9]+)',l)
        newdates2 = newdates2 + 1
        date1 = m[1]
        linkword = m[3]
        date2 = m[4]
        if(re.search('^\-',date1)):
            date2 = '-' + date2
            #print('date2 now',date1,date2,l)
        i = i + 1
        if(i> 100):
            print('outofcontrol1',l)
            break
        if(0 and int(date2) < int(date1)):
            print('newdate',curentryid,curvolume,curpage,date1,linkword,date2,l,end='')
        l = re.sub('<date when-custom="([0-9]+|\-[0-9]+)">([^<]+</date>)(\s+and\s+|\s+or\s+|\s+to\s+|,\s+)([0-9]+|\-[0-9]+)','<date when-custom="\g<1>">\g<2>\g<3> <date when-custom="\g<4>">\g<4></date>',l,1)

    l,hits = re.subn('(</date>)\s*-\s*([0-9]+)','\g<1>-<date when-custom="\g<2>">\g<2></date>',l)
    newdates2 = newdates2 + hits
    

    workl = l
    matchs = '<date when-custom="([0-9\-]+)">([^<]+)</date>-<date when-custom="([0-9\-]+)">'
    while(re.search(matchs,workl)):
        m = re.search(matchs,workl)
        date1 = m[1]
        date2 = m[3]
        if(not len(date1) == len(date2) and int(date1) > int(date2)):
            datemask = re.sub('(.)','.',date2) + '$'
            half1 = re.sub(datemask,'',date1)
            newdate2 = half1 + date2
            if(1 or int(newdate2) < int(date1)):
                print('unmatched',date1,date2,newdate2)
            l = re.sub('when-custom="' + date2+ '"','when-custom="' + newdate2 + '"',l)
        workl = re.sub(matchs,'',workl,1)


    if(re.search('<p>',l)):
        l = re.sub('([A-Z][a-z][a-z]\.)','<abbr>\g<1></abbr>',l)
        l = re.sub('<abbr>'+shortpat+'\.</abbr>','\g<1>',l)
        while(re.search('(="[^"]*|<bibl[^>]*>[^<]*)<[/]*abbr>',l)):
            l = re.sub('(="[^"]*|<bibl[^>]*>[^<]*)<[/]*abbr>','\g<1>',l)
        if(0 and re.search('It is usually stated on the authority of Ephorus',l)):
            print('work',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*\s+[A-Za-z]+[,\s]|[A-Z][a-z]*\s+<[a-zA-Z]+)','\g<1>\n<s n="r01"/>\g<2>',l)
        l,hits = re.subn('(\)\.|\.\)|\.</hi>\)|\.</hi>|\.</foreign>\))\s+([A-Z])','\g<1>\n<s n="r2"/>\g<2>',l)
        l,hits = re.subn('(</date>\.)\s+([A-Z])','\g<1>\n<s n="r3"/>\g<2>',l)
        l,hits = re.subn('(\]\.|\.\)])\s+([A-Z])','\g<1>\n<s n="r4"/>\g<2>',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*,\s+[A-Za-z]+[,\s])','\g<1>\n<s n="r5"/>\g<2>',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*\s+\()','\g<1>\n<s n="r6"/>\g<2>',l)
        l,hits = re.subn('(\.</hi>\])\s+([A-Z])','\g<1>\n<s n="r7"/>\g<2>',l)
        l,hits = re.subn('(\.)\s+(In\s+<date)','\g<1>\n<s n="r8"/>\g<2>',l)
        l,hits = re.subn('(\.</foreign>)\s+([A-Z])','\g<1>\n<s n="r9"/>\g<2>',l)
        l,hits = re.subn('([a-z][a-z]+[\.!?"])\s+([A-Z][a-z]*\s+[A-Za-z]+[,\s]|[A-Z][a-z]*\s+<title)','\g<1>\n<s n="r10"/>\g<2>',l)
        l,hits = re.subn('(</ref>\]|</bibl>\))\s+([A-Z])','\g<1>\n<s n="r11"/>\g<2>',l)

    olymppat = '([0-9]+)([a-z]+\s+Olympiad)'
    while(re.search(olymppat,l)):
        m = re.search(olymppat,l)
        ol = int(m[1])
        startyear = -776 + (4*(ol-1))
        endyear = startyear + 3
        yearrange = str(startyear) + '-' + str(endyear)
        l = re.sub(olymppat,'<date when-custom="'+yearrange+'">\g<1><z/>\g<2></date>',l,1)
    l = re.sub('<z/>','',l)
    
    
    matchs = '([a-zA-Z0-9]+)\s+(century)\s+([AB]\.\s*[DC]\.|after\s+Christ|before Christ)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        if(m[3] == 'after Christ'):
            era = 'A.D.'
        elif(m[3] == 'before Christ'):
            era = 'B.C.'
        else:
            era = m[3]
        curkey = m[1] + ' ' + era
        curkey = re.sub('\.\s+','.',curkey)
        if(not curkey in centval):
            print('missingcentval',curkey,l)
            curval = 'noval'
        else:
            curval = centval[curkey]
        l = re.sub(matchs,'<date when-custom="'+curval+'">\g<1> \g<2> <z/>\g<3></date>',l,1)
    l = re.sub('<z/>','',l)
    
    matchs = '(<hi rend="smallcaps">)([^<,]+)(\s*[;:,]\s+)([A-Z]+)'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        xrefn = xrefn + 1
        key1 = m[2]
        key2 = m[4]

        #print(curentryid,xrefn,key1,key2)
        l = re.sub(matchs,'\g<1>\g<2></hi>\g<3><hi rend="smallcaps">\g<4>',l,1)
        
        continue
        
        
    matchs = '(<hi rend="smallcaps">)([^<]+)</hi>' 
    if(re.search(matchs,l)):
        m = re.search(matchs,l)
        newxref = m[2]
        trykey = newxref.lower() + '-geo'
        if(trykey in entryids):
            res = 'hit'
            l = re.sub(matchs,'<ref target="'+trykey+'" n="U">\g<2></ref>',l,1)

        else:
            res = 'fail'
            xreffails = xreffails + 1
            l = re.sub(matchs,'<hix rend="smallcaps">\g<2></hi>',l,1)
        print(xreffails,curentryid,newxref,res)

    l = re.sub('<hix ','<hi ',l)
    
    print(l,end='',file=outf)
    

f.close()
outf.close()


print('pass 2 done',newdates1,newdates2,places1,titles1,'xrefs',xrefn,xreffails)
# Out:
# pass 1 done
# 1 abbassus-geo ALAMALSSUS fail
# 2 abodiacum-geo ABUZACUM fail
# 3 aborigines-geo LATINI. fail
# 4 aborigines-geo TRIBULA fail
# 5 aborigines-geo BATIA fail
# 6 aborigines-geo COTYLIA fail
# 7 absyrtides-geo APSORRUS fail
# 8 abydus-geo-2 NOMOS THINITES fail
# 9 acalandrus-geo HERACLEA. fail
# 10 acarnania-geo CRANIA. fail
# 11 acarnania-geo B.C. fail
# 11 acarnania-geo ANACTORIUM hit
# 12 ace-geo ACCHO fail
# 13 acerrae-geo-3 VATRIAE fail
# 14 acesines-geo ASINES fail
# 14 achaei-geo CROTON hit
# 15 achaia-geo-2 AEGIALUS fail
# 16 achaia-geo-2 MONS PANACHAICUS fail
# 17 achaia-geo-2 SYS fail
# 18 achaia-geo-2 COTINTHUS. fail
# 19 achaia-geo-2 AEGAE  fail
# 19 acherini-geo ACHERINI hit
# 20 acherusia-geo-palus02 AVERNUS. fail
# 21 acimincum-geo ACUNUM. fail
# 22 aciris-geo ACIDIOS fail
# 23 acrilla-geo ACCILLAE fail
# 24 addua-geo ADULA fail
# 25 adorsi-geo AOASI. fail
# 25 adraa-geo EDREI hit
# 25 adramyenttus-sinus-geo ADRAMYTTIUM hit
# 26 adrans-geo HADRANS fail
# 27 adranum-geo HAITRANUM fail
# 28 adria-geo HATRIA fail
# 29 adria-geo-2 MATRINUM fail
# 30 adria-geo-2 HAT. fail
# 31 adriaticum-mare-geo MARE SUPERUM fail
# 32 aeantium-geo TISAEXUM. fail
# 33 aeculanum-geo ECLANUM) fail
# 34 aeculanum-geo QUINTODECIMUM fail
# 35 aedui-geo AULMECI fail
# 36 aegae-geo-1 AEGA fail
# 36 aegaeum-mare-geo CYCLADES hit
# 37 aegaeum-mare-geo MARE THRACIUM fail
# 38 aegaleos-geo CORYDALUS fail
# 39 aegates-geo PHORBANTIA fail
# 40 aegida-geo JUSTINOPOLIS. fail
# 41 aegilia-geo-1 AEGILUS fail
# 42 aegilia-geo-2 AEGILEIA fail
# 43 aegina-geo B.C. fail
# 44 aegithallus-geo ACELLUM fail
# 45 aegyptus-geo CHEMI fail
# 46 aegyptus-geo OASIS. fail
# 47 aegyptus-geo NOMES OF THE DELTA. fail
# 48 aegyptus-geo NOMES OF THE HEPTANOMIS. fail
# 49 aegyptus-geo NOMES OF UPPER EGYPT. fail
# 50 aegyptus-geo B.C. fail
# 51 aegyptus-geo PSAMMETICHUS fail
# 52 aegyptus-geo NECO fail
# 53 aegyptus-geo PSAMMIS fail
# 54 aegyptus-geo AMASIS fail
# 55 aegyptus-geo AMYRTAEUS fail
# 55 aegyptus-geo BUBASTIS hit
# 56 aenaria-geo EPOMEUS fail
# 57 aeoliae-geo LIPARAEAN fail
# 58 aeoliae-geo-2 VULCANI INSULA fail
# 59 aeoliae-geo-4 DIDYME fail
# 60 aeoliae-geo-7 EUONYMUS fail
# 61 aequi-geo AEQUICULI fail
# 62 aequi-geo NERSAE fail
# 63 aesis-geo AD AESIM fail
# 64 aesula-geo AESULUMI fail
# 65 aethiopia-geo KUSH fail
# 66 aethiopia-geo BLEMMYES fail
# 67 aethiopia-geo CORTE fail
# 68 aetna-geo INESSUM fail
# 69 aetolia-geo DRYOPIS. fail
# 69 aetolia-geo ACHELOUS hit
# 69 aetolia-geo AGRAEI hit
# 69 aetolia-geo CALYDON hit
# 69 africa-geo LIBYA hit
# 70 africa-geo GAETULI fail
# 71 africa-geo NUMIDAE. fail
# 72 africa-geo MASSAESYLII fail
# 73 africa-geo DLXXX. fail
# 73 africa-geo VANDALI hit
# 73 agraei-geo EPHYRA hit
# 74 agri-decumates-geo A.D fail
# 75 agrigentum-geo ACRAGAS fail
# 76 agrigentum-geo PHALARIS fail
# 77 agrigentum-geo AGKIGENTUM fail
# 78 alabis-geo ABOLUS fail
# 79 alaesa-geo ALAESUS fail
# 79 alani-geo AFRICA hit
# 80 alatrium-geo ALATRINATES fail
# 81 alba-longa-geo LATINI. fail
# 82 alba-longa-geo LATINI. fail
# 83 albania-geo CAUCASIAE PYLAE. fail
# 83 albaniae-portae-geo ALBANIA hit
# 84 albanus-lacus-geo B.C. fail
# 85 albinia-geo ALMINIA fail
# 86 albion-geo BRITANNIA. fail
# 87 alexandreia-geo A. D. fail
# unmatched 260 8 268
# 88 alexandreia-geo02-5 AD ISSUM fail
# 89 alexandreia-geo02-6 OXIANA. fail
# 90 alexandreia-geo02-8 COL. AVG. TROAS fail
# 91 alexandreia-geo02-9 ULTIMA fail
# 92 allia-geo ALIA fail
# unmatched 280 81 281
# 93 almopia-geo ALMOPES fail
# 94 ameria-geo02 B.C. fail
# 95 ammonitae-geo PHILADELPHIA fail
# 96 ammonium-geo OASIS. fail
# 97 amorites-geo HESHBON fail
# 98 amphicaea-geo OPHITEIA fail
# 99 amyclae-geo02 SPELUNCAE fail
# 100 anagnia-geo COMPITUM ANAGNINUM fail
# 101 anapus-geo-1 PALUS LYSIMELEIA fail
# 102 anderitum-geo M. P. GABALL. V. fail
# 103 angitiae-lucus-geo FUCINUS. fail
# 104 anio-geo ANIENIS fail
# 105 anitorgis-geo CONISTORSIS. fail
# 106 antigoneia-geo-6 ALEXANDREIA TROAS fail
# 107 antinum-geo ATINATES fail
# 108 antiocheia-geo B.C. fail
# 109 antiocheia-geo02-2 MYGDONIAE. [NISIBIS.] fail
# 110 antiocheia-geo02-3 CILICIAE fail
# 111 antiocheia-geo02-4 AD CRAGUM fail
# 112 antiocheia-geo02-5 AD MAEANDRUM fail
# 113 antiocheia-geo02-7 PISIDIAE fail
# 114 antiocheia-geo02-7 ANTIOCHEAE CAESARE fail
# 115 antiocheia-geo02-8 AD TAURUM fail
# 116 antiquaria-geo ANTIK. fail
# 117 antitaurus-geo TAURUS. fail
# 118 antium-geo CENO fail
# 119 antivestaeum-geo BELLERIUM. fail
# 120 antonini-vallum-geo BOTANNIA. fail
# 121 antron-geo ROMANS fail
# 122 aous-geo ANIUS fail
# 123 apanestae-geo APAENESTINI fail
# 124 aparni-geo PARNI. fail
# 125 apavarcticene-geo APAVORTENE fail
# 126 apenninus-mons-geo VULTUR. fail
# 127 apenninus-mons-geo MONS FISCELLUS fail
# 128 aphrodites-portus-geo MYOS HORMUS. fail
# 129 aphroditopolis-geo ATARBECHIS. fail
# 130 apollinis-geo-promontorium-1 PULCHRUM PR. fail
# 131 apollinopolis-geo-1 APOLLINOPOLIS MAGNA fail
# 132 apollinopolis-geo-2 APOLLINOPOLIS PARVA fail
# 133 apollinopolis-geo-3 APOLLINOPOLIS PARVA fail
# 134 apollinopolis-geo-5 APOLLONOS HYDREIUM fail
# 135 apolloniatis-geo APOLLOIA. fail
# 136 apulia-geo PEDICULI fail
# 137 apulia-geo APULI fail
# 138 apulia-geo DAUNIANS fail
# 139 apulia-geo FIENTO fail
# 140 apulia-geo SINUS URIAS fail
# 141 apulia-geo INSULAE DIOMEDEAE fail
# 141 apulia-geo LUCERIA hit
# 142 apulum-geo AP. fail
# 143 aquae-bormonis-geo BORBONI THERMARUM DEO MAMMONAE fail
# 144 aquae-hispanicae-geo BILBITANORUM fail
# 145 aquae-lesitanae-geo LESA. fail
# 146 aquae-passeris-geo AQUAE PAS-SERIANAE. fail
# 147 aquae-patavinae-geo APONI FONS. fail
# 148 aquae-volaterranae-geo VOLATEBRRA. fail
# 149 aquilonia-geo-2 AKIDVNNIV fail
# 150 aquitania-geo GALLIA. fail
# 151 aquitania-geo ARMORICA. fail
# 152 ar-geo MOABITIS. fail
# 153 ara-ubiorum-geo A. fail
# 154 arabia-geo COELE SYRIA fail
# 155 arabia-geo ARABIA DESERTA fail
# 155 arabia-geo SABA hit
# 156 arabia-geo MIDIAN. fail
# 157 arabia-geo NABATHAEI fail
# 157 arabia-geo AMMONITAE hit
# 158 arabia-geo NABATHAEI fail
# 158 arabia-geo IDUMAEA hit
# 158 arabia-geo PETRA hit
# 158 arabia-geo PETRA hit
# 159 arabia-geo NABATHAEI fail
# 160 arabia-felix-geo ATTANAE fail
# 161 arabicus-sinus-geo MYOS HORMOS fail
# 162 arachosia-geo ARACHIOTUS fail
# 163 arae-alexandri-geo ALEXANDRI ARAB. fail
# 164 arae-philaenortum-geo SYRTES. fail
# 165 ararat-geo AARENIA. fail
# 166 arbelitis-geo ERECH fail
# 166 arcadia-geo02 STYX hit
# 166 arcadia-geo02 STYMPHALUS hit
# 167 aremorica-geo ARMORICA. fail
# 168 arenae-montes-geo MALXRIANU. fail
# 169 aretias-geo02 ARIAS. fail
# 170 argentarius-mons-geo PORTUS HERCULTS fail
# 171 argentoratum-geo AROENTARIA. fail
# 172 argidava-geo ARCIDAVIA. fail
# 173 argos-geo ARGOLICE fail
# 173 argos-geo LYRCEIA hit
# 174 argos-geo GFENESIUM fail
# 175 argos-geo TEMENION fail
# 176 argos-geo ARGI fail
# 177 argos-geo B.C. fail
# 178 argos-geo CYLARABIS fail
# 179 argos-geo NAUSLIA. fail
# 179 argyrini-geo ANTIGONEIA hit
# 180 aria-geo02 ARIA. CNARIA. CUNBARIA. fail
# 180 ariana-geo ARACHOSIA hit
# 181 aricia-geo B. C fail
# 182 aricia-geo VALLIS ARICINA fail
# 183 aricia-geo LACUS NEMORENSIS fail
# 184 aricia-geo MONS ARTEMISIUS fail
# 185 ariminum-geo S. V. fail
# 186 ariminum-geo ARIMINIUS fail
# 187 ariolica-geo-1 ARTOLICA fail
# 188 aristonautae-geo PEILENE. fail
# 189 armenia-geo MINNI fail
# 189 armenia-geo ARAXES hit
# 190 armenia-geo MANTIANE fail
# 190 armenia-geo TIGRANOCERTA hit
# 191 armozon-prom-geo HARMOZON. fail
# 192 aroanius-geo-1 ANIAS fail
# 193 arpinum-geo ARX  fail
# 194 arrabo-geo-2 ARRABONE fail
# 195 arsamosata-geo ARMOSATA. fail
# 196 arsinoe-geo-7 TAUCHEIRA. fail
# 197 artacene-geo ARACTENE. fail
# 198 artigi-geo ARTIGI JULIENSES fail
# 199 arva-geo ORDO MUNICIPII. FLAVII. ARVENSIS. fail
# 200 ascania-lacus-geo ANAYA fail
# 201 asculum-geo-1 AUSCULUM fail
# 202 asia-geo ASIS fail
# 203 asia-geo ASIA MINOR fail
# 204 asia-geo B.C. fail
# 205 asia-geo PALIBOTHRA fail
# 205 asia-geo PAROPAMISUS hit
# 206 asia-geo ASIA MINOR fail
# 207 asia-geo TAURUS fail
# 208 asinarus-geo HEELORUM. fail
# 209 asopus-geo-1 PARASOPIA. fail
# 210 asopus-geo-6 LAODICEA AD LYCUM. fail
# 211 aspasii-geo GORYDALA fail
# 212 assa-geo CASSERA fail
# 213 assacani-geo GURAEI fail
# 214 assacani-geo MASSACA fail
# 215 asta-geo02 AST fail
# 216 asta-geo02 P. COL. ASTA. RE. F. fail
# 217 astacus-geo02 NICOMEDIA fail
# 218 astigi-geo-1 ASTIGITANA COLONIA AUGUST FIRMA fail
# 219 astigi-geo-2 ASTIGI VETUS fail
# 220 astigi-geo-3 JULIENSES. [ARTIGI.] fail
# 221 astures-geo AUGUSTANI fail
# 222 astures-geo ARGENTIOLUM fail
# 223 asturica-augusta-geo COL. AST. AUGUSTA. fail
# 224 ateste-geo MONS SILICIS fail
# 225 athenae-geo-1 DIADES fail
# 226 athenae-geo03 MUSEIUM. fail
# 227 athenae-geo03 ERECHTHEIUM. fail
# 228 athenae-geo03 C.IVLIVS C. F.FAB fail
# 229 athenae-geo03 B.C. fail
# 230 athenae-geo03 ZEA fail
# 231 athenae-geo03 THE HARBOUR fail
# 231 athos-geo DIUM hit
# 232 athrys-geo TANTRUS. fail
# 233 atina-geo-2 ATINATES fail
# 233 atlanticum-mare-geo LIBYA hit
# 234 atlanticum-mare-geo BRITANNIA fail
# 235 atlanticum-mare-geo OCEANUS GADITANUS fail
# 236 atlantis-geo FORTIJNATAE INSULAE. fail
# 236 atlas-geo MAURETANIA hit
# 237 atlas-geo TRITONIS fail
# 238 atlas-geo GER. fail
# 239 atlas-geo ATLAS MINOR fail
# 240 attacum-geo MUNICIP. ATTACENS. fail
# 240 attica-geo CERAMEICUS hit
# 241 attica-geo PHORON LIMEN fail
# 242 attica-geo OE fail
# 243 attica-geo OE fail
# 244 attica-geo LACIADAE fail
# 245 attica-geo CEPHISIA fail
# 246 attica-geo CEPHISIA fail
# 247 attica-geo ATHMONUM fail
# 248 attica-geo ATHMONUM fail
# 249 attica-geo AGNUS fail
# 250 attica-geo AGNUS fail
# 251 attica-geo ATHINAE fail
# 252 attica-geo RIHAMNUS. fail
# 253 attica-geo EPACRIA fail
# 254 attica-geo EPACRIA fail
# 255 attica-geo PHEGEUS fail
# 256 attica-geo ELEUSSA fail
# 257 attica-geo PANEIUM fail
# 258 attica-geo MARONE1A fail
# 259 auasis-geo OASIS. fail
# 260 augusta-vagiennorum-geo AUG. BAG. fail
# 260 aulerci-geo CENOMANI hit
# 261 aulon-geo03-2 COELE SYRIA. fail
# 262 aurgi-geo MUNICIPIUM FLAVIUM AURGITANUM. fail
# 263 aurunci-geo B.C. fail
# 263 ausa-geo AUSA hit
# 263 ausones-geo-3 AUSONIA hit
# 264 autissiodurum-geo APPOLLINI R. P. II. M. AUTESSIODURUM. fail
# 265 auxacii-geo OXII fail
# 266 auxume-geo A. D. fail
# 267 auza-geo COLONIA AUZIENSIS fail
# 268 auzacia-geo AUXACII MONTES. fail
# 269 aventicum-geo TIGURINI fail
# 270 axiaces-geo PASIACES. fail
# 271 axiopolis-geo MUTATIO GEPHYRA fail
# 272 azetium-geo AEGETINI fail
# 273 baalbek-geo HELIOPOLIS. fail
# 274 babylonia-geo TEREDON OR DIRIDOTIS fail
# 274 babylonia-geo EUPHRATES hit
# 274 bactrus-geo BACTRA hit
# 275 baedyes-geo GALLAECI. fail
# 276 baetis-geo CERTIS fail
# 277 baetis-geo ARGENTARIUS fail
# 278 bagrada-geo MAMPSARUS fail
# 279 bagrada-geo PAGIDA fail
# 280 bagrada-geo MT. USARGALA fail
# 281 baleares-geo BALEARIS MAJOR fail
# 282 baleares-geo BAL fail
# 283 baleares-geo PRAEF. PRAE LEGATO INSULAR. BALIARUM. fail
# 284 baleares-geo BALEARIS MAJOR fail
# 285 baleares-geo MINOR fail
# 286 balesium-geo BALENTIUM fail
# 287 balla-geo BALA fail
# 288 baltia-geo AVARI fail
# 289 banadedari-geo ARAE PHILAENORUM. fail
# 290 bandusiae-fons-geo BLANDUSIA fail
# 291 banienses-geo NORBA CAESAREA. fail
# 292 barbarium-geo PR. fail
# 293 barca-geo TEUCHIRA fail
# 293 barca-geo BARCAEI hit
# 293 barcaea-geo BARCA hit
# 294 barcaei-geo BARCITAE fail
# 295 barcino-geo COL. BARCINO. FAVENTIA. fail
# 296 basta-geo BASTERBINI fail
# 297 bastetani-geo BASTETANIA fail
# 298 bastia-geo MENTESA BASTIA. fail
# 299 belgae-geo GALLIA. fail
# 300 belgae-geo02 BIBROCI. fail
# 301 belgica-geo GALLIA. fail
# 302 belginum-geo GALLIA. fail
# 303 belon-geo BAILO. fail
# 304 benacus-lacus-geo BENACENSES fail
# 305 beneventum-geo BENVENTOD fail
# 306 benjanin-geo PALESTINA. fail
# 307 berenice-geo-2 PANCHRYSOS fail
# 308 berenice-geo-3 EPIDEIRES fail
# 309 berones-geo CELTIBERI fail
# 310 bethel-geo LUZ fail
# 311 bethhaccarem-geo HERODIUM. fail
# 312 bethhogla-geo BETHAGLAO. fail
# 313 bethogabris-geo ELEUTFEROPOLTS fail
# 314 bethshemesh-geo BETHJESIMOTH. fail
# 315 bilbilis-geo AQUAE BILBITANAE fail
# 316 bisaltia-geo ARGILJUS. fail
# 317 bithyas-geo BAITHYNIAS. fail
# 318 bithyni-geo BITYNIA. fail
# 319 bithynia-geo ASCANIA fail
# 320 bizone-geo S. V. fail
# 321 blemyes-geo A. D. fail
# 322 blendium-geo CANTABRI. fail
# 323 bodiontici-geo AVANTIC fail
# 324 boeotia-geo COPAIS fail
# 324 boeotia-geo HYPHANTEIUM hit
# 325 boeotia-geo PTOUN fail
# 326 boeotia-geo PHOENICIUM fail
# 327 boeotia-geo LEIBETHRIUM fail
# 328 boeotia-geo THIURIUM fail
# 329 boeotia-geo ISOMANTUS fail
# 330 boeotia-geo HYLICA fail
# 331 boeotia-geo LEOPUS fail
# 332 boeotia-geo TENERIC PLAIN fail
# 333 boeotia-geo PLATAEAE fail
# 334 boeotia-geo HYPATUS fail
# 335 boeotia-geo CFERYCEIUM fail
# 335 boeotia-geo MINYAE hit
# 335 boeotia-geo ORCHOMENUS hit
# 336 boeotia-geo UPPER LARYMNA fail
# 337 boeotia-geo CHORSEIA fail
# 337 boeotia-geo HYLE hit
# 338 boeotia-geo PLATAEAE fail
# 338 bononia-geo FELSINA hit
# 339 bora-geo BERMIUS. fail
# 340 boreum-geo-1 SYRTES. fail
# 341 bormanum-geo DACTA. fail
# 342 bosporus-cimmerius-geo ACRA fail
# 343 bosporus-thracius-geo AIANTEION fail
# 344 bosporus-thracius-geo ANCYRAEUM PROMONTORIUM fail
# 345 bostra-geo BOTZRAH fail
# 346 bostra-geo NOVA TRAJANA ALEXANDRIANA COL. BOSTRA. fail
# 347 braccium-geo IMP. CAES. L. SEPTIMIO fail
# 348 brettia-geo BRITANNIA. fail
# 349 britannicae-insulae-geo B.C. fail
# 350 britannicae-insulae-geo BRITANNIA PROPER. fail
# 351 britannicae-insulae-geo TASCIOVANUS fail
# 352 britannicae-insulae-geo ANGLI fail
# 353 britannicae-insulae-geo DEO SANCTO fail
# 354 britannicae-insulae-geo MURIDUNUM fail
# 355 britannicae-insulae-geo VALLUM. fail
# 355 britannicae-insulae-geo CALEDONIA hit
# 356 bromiscus-geo ARETHIUSA fail
# 357 bruttii-geo LACINIAN fail
# 358 bruttii-geo OENOTRIANS fail
# 359 bruttii-geo B.C. fail
# 360 bruttii-geo LAUS fail
# 361 bruttii-geo LIGEA fail
# 362 bruttii-geo CERILLI fail
# 363 bubastis-geo PHIBESETH fail
# 364 bubon-geo BALBURA  fail
# 365 budeium-geo BUDEIA fail
# 366 budorus-geo-1 CERINTIUS. fail
# 367 budorus-geo-2 SALAMS. fail
# 368 buthrotum-geo PELODES fail
# 369 byblos-geo02 A. D. fail
# 370 byce-geo BUCE. fail
# 371 byzacium-geo ZEUGITANA fail
# 372 byzacium-geo PROV. VAL. BYZACENA fail
# 372 cabalis-geo BALBURA hit
# 372 caecinus-geo HALEX hit
# 373 caena-geo CAESNE fail
# 374 caenica-geo CAENI fail
# 375 caere-geo TARCHNAS fail
# 376 caesaraugusta-geo C. A. fail
# 377 caesareia-geo-3 AD ANAZARBUM. fail
# 378 caieta-geo SINUS CAIETANUS fail
# 379 calabria-geo SALLNTINI fail
# 380 calabria-geo CALABRI fail
# 381 calabria-geo BRUNDUSIUM fail
# 382 calagurris-geo NASSICA fail
# 383 calagurris-geo NASSICA fail
# 384 calagurris-geo CAESAIAUGUSTA. fail
# 385 calarna-geo ARINAE. fail
# 386 calatia-geo-1 CAIATINO. fail
# 387 calatum-geo GALATUM. fail
# 388 calcua-geo NALCUA. fail
# 389 cale-geo CALADUNUM fail
# 389 caledonia-geo PICTI hit
# 390 caledonia-geo BRITANNIA. fail
# 391 calingae-geo CALINGON fail
# 392 calingae-geo CALINGAE GANGARIDES fail
# 393 callaici-geo GALLAECI. fail
# 393 calpe-geo ABYLA hit
# 394 calpe-geo CARTEIA fail
# 395 calpe-geo CARTEIA. fail
# 396 calpia-geo CARTEIA. fail
# 397 camacha-geo GAMAKH fail
# 398 camarina-geo B.C. fail
# 399 camarina-geo OANIS fail
# 400 camerinum-geo CAMERINI fail
# 401 campania-geo MONS CALLICULA fail
# 402 campania-geo MONS GAURUS fail
# 403 campania-geo SINUS CUMANUS fail
# 404 campania-geo LITERNUS. fail
# 405 campania-geo MONS LACTARIUS fail
# 406 campania-geo AVERNUS fail
# 406 campania-geo AENARIA hit
# 406 campania-geo CUMAE hit
# 407 campi-phlegraei-geo LABORIAE fail
# 408 candidum-promontorium-geo PULCHRUM PROMONTORIUM fail
# 409 candyba-geo KAND fail
# 410 canonium-geo CAMELODUNUM fail
# 411 cantaber-oceanus-geo CANTABRI fail
# 412 cantabras-geo SANDABAL fail
# 412 cantabria-geo AUTRIGONES hit
# 413 cantabria-geo JULIOBRICA fail
# 414 cantae-geo CANTIUM PROMIONTORIUM fail
# 415 canthi-sinus-geo SYRASTRENE fail
# 416 caphyae-geo RHEUNUS fail
# 417 cappadocia-geo PONTUS GALATICUS fail
# 418 capraria-geo AEGILIUM fail
# 418 capraria-geo02 BALEARES hit
# 419 capria-lake-geo ASPENNDUS. fail
# 420 capua-geo AGER CAMPANUS fail
# 421 caraceni-geo CARICINI fail
# 422 caralis-geo CARALITANUM PROMONTORIUM fail
# 423 caranitis-geo ARZEK fail
# 424 carduchi-geo CORDUENE. fail
# 425 carmana-geo CARPMANIA. fail
# 426 carmelus-mons-geo PORPHYRIUM fail
# 426 carni-geo VENETIA hit
# 427 carpeia-geo CARTEIA. fail
# 428 carpessus-geo CARTEIA. fail
# 429 carpetani-geo CARPETANIA fail
# 430 carpetani-geo CARTEIA fail
# 431 carpia-geo CARTEIA. fail
# 432 carrhae-geo HARAN fail
# 433 carteaia-geo CAR. KAR. CART. CARTECIA. fail
# 434 carteaia-geo BASTULI POENI. fail
# 435 carteaia-geo CALPE CARTEÎAM fail
# 436 carteaia-geo CARTH. fail
# 436 carteaia-geo CARPETANI hit
# 437 carthago-geo CARTACO. fail
# 438 carthago-geo BYRSA fail
# 439 carthago-geo BIRTH OF ABRAHAM. fail
# 440 carthago-geo TAKING OF TROY. fail
# 441 carthago-geo FOUNDATION OF ROME. fail
# 442 carthago-geo CHRISTIAN ERA. fail
# 443 carthago-geo SITE OF CARTHAGE fail
# 444 carthago-geo TYPUS fail
# 444 carthago-geo UTICA hit
# 444 carthago-geo AUSENSES hit
# 445 carthago-geo MAURENTANIA fail
# 446 carthago-geo ARAE PHILAENORUM. fail
# 447 carthago-geo ZEJGITANA fail
# 448 carthago-geo B.C. fail
# 449 carthago-geo HASDRUBAL fail
# 449 carthago-geo MOTYA hit
# 450 carthago-geo ARAE PHILAENORUM. fail
# 451 carthago-geo B.C. fail
# 452 carthago-geo B.C. fail
# 453 carthago-geo B.C. fail
# 454 carthago-geo ALL fail
# 454 carthago-geo TRITON hit
# 455 carthago-geo ARAE PHILAENORUM fail
# 456 carthago-geo SOLOEIS. fail
# 456 carthago-geo SICILIA hit
# 456 carthago-geo AFRICA hit
# 457 carthago-geo JUNONIA fail
# 458 carthago-geo FELIX KART. fail
# 459 carthago-geo BYRSA fail
# 460 carthago-nova-geo COLONIA VICTRIX JULIA NOVA CARTHAGO fail
# 461 carthago-nova-geo CARTHAGO SPARTARIA fail
# 462 carthago-nova-geo V. I. N. K. fail
# 463 carvetii-geo D. M. fail
# 464 casci-geo LATINI. fail
# 465 casia-regio-geo CASII M. fail
# 466 casii-montes-geo BAUTIS. fail
# 467 casinum-geo CASINUS fail
# 468 caspeiria-ins-geo FORTUNATAE. fail
# 469 caspium-mare-geo MARE HYRCANIUM fail
# 470 cassandres-geo GASANDI. fail
# 470 cassiotis-geo ANTIOCHEIA hit
# 471 cassope-geo CASSOPAEI fail
# 472 castellani-geo IACCETANI fail
# 473 castulo-geo VRR. fail
# 474 casuarii-geo CHASNARI. fail
# 475 catarrhactes-geo ATTALIA fail
# 476 catenneis-geo ETENNEIS. fail
# 477 caucasus-geo SARMATIANS fail
# 478 caucasus-geo PEITHEIROPHAGI fail
# 479 caucasus-geo CERAUNII M. fail
# 480 caucasus-geo CERAUNII M. fail
# 481 caudium-geo FURCULAE CAUDINAE fail
# 482 caulonia-geo CROTONA fail
# 482 caunii-geo CARIA hit
# 483 causennis-geo DUROBRIVIS. fail
# 484 caystri-campus-geo CAYSTER. fail
# 485 cecilionicum-geo CXXXI. fail
# 486 celtae-geo GALLIA. fail
# 487 celtiberia-geo CELTICI fail
# 487 celtiberia-geo ANAS hit
# 487 celtiberia-geo NUMANTIA hit
# 488 celtiberia-geo SEGEDA fail
# 489 celtica-geo GALLIA. fail
# 490 celtica-geo02 CELTIBERI fail
# 490 celtica-geo02-2 CONISTORGIS hit
# 491 celtica-geo02-3 CUGIGA fail
# 492 celtica-geo02-4 CELTICUM fail
# 493 celticum-promontorium-geo CELTICI. fail
# 494 cenchreae-geo-1 CEBRFENIA fail
# 495 ceos-geo CEA fail
# 496 cephalae-geo BOREUM PR. fail
# 497 cephallenia-geo BAEA fail
# 498 cephallenia-geo TAPHUS fail
# 498 cephissis-lacus-geo BOEOTIA hit
# 498 cerameicus-geo BUBASSUS hit
# 499 cerasae-geo BAGAE. fail
# 500 ceraunii-geo-montes02 ACROCERAUNII fail
# 501 cercinitis-geo PRASIAS fail
# 502 ceresus-geo IACCETANI. fail
# 503 cerne-geo LIXUS fail
# 503 ceryceium-geo BOEOTIA hit
# 504 cesada-geo AREVACAE. fail
# 505 cevenna-geo CEBENNA. fail
# 506 chaboras-geo CHABURA fail
# 507 chaboras-geo CHABORA fail
# 508 chala-geo CELONAE fail
# 509 chalcidice-geo B.C. fail
# 509 chalcidice-geo GIGONUS hit
# 509 chalcidice-geo STRATONICE hit
# 510 chalcis-geo-2 AD BELUM. fail
# 511 chalcis-geo02-2 CHALCEIA fail
# 512 charieis-geo CHARES fail
# 513 chasuari-geo ATTUARII fail
# 514 chatramis-geo CORODAMUM PROMONTORIUM. fail
# 515 chemmis-geo BUTO. fail
# 516 chersonesus-aurea-geo AUREA. fail
# 516 chersonesus-thracica-geo CARDIA hit
# 517 cherusci-geo HARZ fail
# 518 chesinus-geo SARMATIA EUROPAEA. fail
# 519 chios-geo ATARSNEUS fail
# 520 chones-geo CHONIA. fail
# 521 chorzane-geo ACILISENE fail
# 522 chronos-geo SARMATIA EUROPAEA. fail
# 522 chrysaorium-geo CARIA hit
# 522 cibyra-geo-1 BUBON hit
# 523 cibyra-geo-2 CIBYRA THE LESS fail
# 524 cierus-geo PRUSA AD HYPIUM. fail
# 525 cilbiani-geo CAYSTER. fail
# 526 cilicia-geo AMANIDES. fail
# 527 cimbrica-chersonesus-geo CHEIRSONESUS CIMBRICA. fail
# 528 ciminus-geo SILVA CIMINIA fail
# 528 cinaedocolpitae-geo DEBAE hit
# 529 circesium-geo CARCHEMISH. fail
# 530 cirrha-geo CRISA. fail
# 531 cissa-geo CINNA fail
# 532 citharizon-geo ASTHIANENE fail
# 533 cius-geo ASCANIA. fail
# 534 cius-geo BRYLLIUM. fail
# 535 clampetia-geo LAMPETES fail
# 536 clauda-geo GAUDOS fail
# 537 clevum-geo GLEVA. fail
# 538 cludrus-geo EUMENIA. fail
# 538 cnopus-geo BOEOTIA hit
# 539 coenyra-geo THASUS. fail
# 540 colonia-agrippina-geo A. D. fail
# 541 comana-geo-1 IN PONTUS fail
# 542 comana-geo-2 IN CAPPADOCIA fail
# 543 cominium-geo BC.. fail
# 544 commagene-geo ANTIOCHUS I. fail
# 545 compulteria-geo KVPELTERNVM fail
# 546 condate-geo02 CONDATE--DEVA M. P. XX. fail
# 547 conderates-geo D. M. fail
# 548 confluentes-geo AMBIATINUS. fail
# 549 constantinopolis-geo NEW ROME fail
# 550 constantinopolis-geo HE fail
# 551 constantinopolis-geo REGION. fail
# 552 constantinopolis-geo REGION. fail
# 553 constantinopolis-geo REGION. fail
# 554 constantinopolis-geo REGION. fail
# 555 constantinopolis-geo REGION. fail
# 556 constantinopolis-geo REGION. fail
# 557 constantinopolis-geo REGION. fail
# 558 constantinopolis-geo REGION. fail
# 559 constantinopolis-geo REGION. fail
# 560 constantinopolis-geo REGION. fail
# 561 constantinopolis-geo REGION. fail
# 562 constantinopolis-geo REGION. fail
# 563 constantinopolis-geo REGION. fail
# 564 constantinopolis-geo REGION. fail
# 565 constantinopolis-geo PRAEFECTUS PRAFTORIO ILLYRIC fail
# 566 constantinopolis-geo PRAEFECTUS PEAETORIO ORIENTIS. fail
# 567 contestani-geo MENLARIA fail
# 568 contrebia-geo-2 CONTREBIA LEUCAS fail
# 568 copais-lacus-geo BOEOTIA hit
# 569 coptos-geo A. D. fail
# 569 coralius-geo BOEOTIA hit
# 570 corcyra-geo LEUCIMME fail
# 571 corcyra-geo MELITEIUM fail
# 572 corduba-geo PATRICIA fail
# 572 corduba-geo CORDUBA hit
# 572 coressus-geo EPHESUS hit
# 573 corinthus-geo SITUATION. fail
# 574 corinthus-geo HISTORY. fail
# 575 corinthus-geo COLONIA IVLIA CORINTHVS fail
# 576 corinthus-geo ART fail
# 577 corinthus-geo TOPOGRAPHY OF THE CITY AND OF THE. PORT-TOWNS. fail
# 578 corinthus-geo COLONIAL COIN OF CORINTH. fail
# 579 corinthus-geo C.L.I. COR. fail
# 580 corinthus-geo THE ISTHMUS. fail
# 581 corinthus-geo TOPOGRAPHY OF THE CORINTHIA. fail
# 582 corinthus-geo SOLYGEIUS fail
# 583 corinthus-geo PEIRAEUM fail
# 584 corinthus-geo ESCHATIOTIS fail
# 585 cornabii-geo-2 DEUNA. fail
# 586 corniculum-geo MONTES CORNICULANI fail
# 586 coros-geo CORIUS hit
# 587 cortona-geo CORYTHUS fail
# 588 cory-geo COLCHI fail
# 589 corytheis-geo TEGFA. fail
# 590 cotylius-geo PHIGALEA. fail
# 591 crater-geo CUMAEAN GULF fail
# 592 cremna-geo COL. IVL. AVG. CREMNA. fail
# 593 creta-geo CNOSSUS fail
# 594 cretopolis-geo CLTMAX fail
# 595 crociatonum-geo CRONCIACONNUM fail
# 596 cromi-geo CROMITIS fail
# 597 croton-geo B.C. fail
# 598 cryassus-geo CHALCE fail
# 599 cumae-geo B.C. fail
# 600 cunarus-mons-geo APENNINUS. fail
# 601 cuneus-geo SACRUM PR. fail
# 602 cupra-geo-1 CUPRA MARITIMA fail
# 603 cupra-geo-2 CUPRA MONTANA fail
# 604 curubis-geo COL. FULVIA. CURUBIS. fail
# 605 cutiliae-geo CUTILIAE LACUS fail
# 606 cutiliae-geo AMSANCTI VALLIS. fail
# 607 cyaneae-insulae-geo BOSPORUS fail
# 608 cydrara-geo CARUPA. fail
# 609 cyllene-geo-1 CHELYDOREA fail
# 610 cynuria-geo THYREATIS fail
# 610 cyphanta-geo CYNURIA hit
# 611 cyrenaica-geo PENTAPOLIS LIBYAE fail
# 611 cyrenaica-geo CYRENE hit
# 612 cyrenaica-geo CATABATHMUS MAJOR fail
# 613 cyrenaica-geo BORBUM PR. fail
# 614 cyrenaica-geo BATTUS fail
# 615 cyrenaica-geo SYRTES fail
# 615 cyrene-geo CYRENAICA hit
# 615 cyrene-geo ASBYSTAE hit
# 616 cyrene-geo FLAVIA. fail
# 617 cyrene-geo ARAE PHILAENORUM fail
# 617 cyrrhestica-geo HIERAPOLIS hit
# 618 cyrtones-geo CYRTONE fail
# 618 cyrus-geo-1 CAMBYSES hit
# 619 cytae-geo CUTATESIUM. fail
# 620 dabanas-geo DARANA fail
# 621 dacia-geo DACIA AURELIANI fail
# 622 dacia-geo PROVINCIA DACIA. fail
# 623 dahae-geo PARNI fail
# 624 damascus-geo HELIOPOLIS fail
# 625 damnii-geo CIVITAS DUMNI fail
# 626 damnonium-geo DUMNONII. fail
# 627 danubius-geo DANUVIUS fail
# 628 dascylium-geo APOLLONIAE fail
# 629 dassaretae-geo LYCHNIDUS. GERUNIUM fail
# 630 deitania-geo CONTESTANIA. fail
# 631 delos-geo RHENAIA fail
# 632 delphi-geo SITUATION. fail
# 633 delphi-geo HISTORY. fail
# 634 delphi-geo TOPOGRAPHY. fail
# 635 delphi-geo LESCHE fail
# 636 delphi-geo DELPHUSA fail
# 637 delphi-geo MODERN AUTHORITIES. fail
# 638 deorum-geo FORTUNATAE. fail
# 639 derangae-geo DRANGAE. fail
# 640 derrhium-geo DERA fail
# 640 deucaledonicus-oceanus-geo DICALEDONAE hit
# 641 dia-geo03 BOSPORUS fail
# 641 diablintes-geo AULERCI hit
# 642 dianium-geo FERRARIA fail
# 643 dictamnum-geo DICTYNNA fail
# 644 dictynnaeum-geo02 PR. [CADISTUS.] fail
# 645 didyme-insula-geo AEOLIAE INS. fail
# 646 diniae-geo METROPOLITANUS CAMPUS fail
# 647 diomedeae-insulae-geo ISOLE DI TREMITI fail
# 648 dioscurias-geo SOTERIOPOLIS fail
# 649 dium-geo-1 BAPHYRUS fail
# 650 doberus-geo DOBERES fail
# 651 docimia-geo BEUDUS fail
# 652 dodona-geo PAMBOTIS fail
# 653 domanitis-geo DOMANETIS. [PAPHLAGONIA.] fail
# 654 dora-flumen-geo DARGOMENES. fail
# 654 doris-geo ERINEUS hit
# 655 drangiana-geo DRANGAE fail
# 656 drepane-geo HELENOPOLIS. fail
# 657 drepanum-geo04 CORYUS PSACUM fail
# 658 drium-geo GARANUS. fail
# 659 drymus-geo-1 DRYAIAEA. fail
# 660 dunum-geo-2 D. SINUS fail
# 661 duodecimum-geo-2 DUODECIMITM fail
# 662 dura-geo-2 DURA NICANORIS. fail
# 663 duretie-geo DARIORIGUM. fail
# 664 durius-geo CUDA fail
# 665 durobrivae-geo02 DORN fail
# 666 durocornovium-geo CORINEIUM. fail
# 666 durocornovium-geo DEVA hit
# 667 durvus-mons-geo VIA DVCTA PER MONTEM DVRVVM fail
# 668 dyme-geo TEICHOS fail
# 669 dyrrhachium-geo B.C. fail
# 670 dyrrhachium-geo B.C. fail
# 671 eboracum-geo EBVRACVM fail
# 672 eboracum-geo DEO. SANCTO. SERAPI. TEMPLVM. ASO fail
# 673 eboracum-geo EBVR fail
# 674 ebrodunum-geo CATUPIGES. fail
# 675 ebura-geo-2 EBURA CEREALIS fail
# 676 eburovices-geo AULEMCI. fail
# 677 ecbatana-geo A. D. fail
# 678 ecdippa-geo ACHZIB fail
# 679 echinades-geo DOLICHA fail
# 680 edetani-geo EDETANIA fail
# 681 edones-geo EÎON fail
# 682 elaius-geo PHIGALEA. fail
# 683 elaver-geo LIGERIS. fail
# 684 elcebus-geo HELVETUS. fail
# 685 eldimaei-geo ELYMAEI. fail
# 686 elephantine-geo EBO fail
# 687 elis-geo ELIS PROPER fail
# 688 elis-geo HOLLOW ELIS fail
# 689 elis-geo PHSELLON fail
# 690 elis-geo HISTORY. fail
# 691 elis-geo PYLOS. fail
# 692 elis-geo THE CITY OF ELIS. fail
# 692 elis-geo BUPRASIUM hit
# 693 elis-geo TOWNS IN ELIS. fail
# 693 elis-geo HYRMINE hit
# 693 elis-geo ALESIAEUM hit
# 693 elis-geo SAMICUM hit
# 694 ellebri-geo VELIBORI. fail
# 695 elleporus-geo HELLEPORUS. fail
# 696 elycoci-geo ALBA HELVIORUM. fail
# 697 elymais-geo-1 ELAM fail
# 697 emathia-geo BEROEA hit
# 698 emodi-montes-geo BEPYRRHUS fail
# 699 enea-geo NEA fail
# 700 enna-geo MUN. fail
# 701 eordaea-geo BEGORRA fail
# 702 epamanduodurum-geo XXXXIIX fail
# 703 epeiacum-geo AXELLODUNUM fail
# 703 epeirus-geo THYAMIS hit
# 704 epeirus-geo B.C. fail
# 704 epeirus-geo-1 PALAESTE hit
# 705 epeirus-geo-2 EUROEA (?) fail
# 705 epeirus-geo-3 PHOTICE hit
# 706 ephesus-geo CAESAREA fail
# 707 epidaurus-geo02 CYNORTIUM fail
# 708 epitalium-geo THRYOESSA fail
# 709 eretria-geo-1 CROMAE fail
# 709 eretria-geo-1 AMARYNTHUS hit
# 710 ericusa-geo AEOLIAE INSULAE. fail
# 711 eridanus-geo PO fail
# 712 eridanus-geo ELECTRIDES INSULAE fail
# 712 erythrae-geo02 CORYCUS hit
# 713 eryx-geo MONS ERYX fail
# 714 etruria-geo ETRUSCI fail
# 715 etruria-geo CIMINUS MONS. fail
# 716 etruria-geo LACUS TRASIMENUS fail
# 717 etruria-geo MONS ARGENTARIUS fail
# 718 etruria-geo GALLIA CISALMPINA fail
# 719 etruria-geo TARQUINIUS. fail
# 720 etruria-geo B.C. fail
# 721 etruria-geo CUSIUM. fail
# 722 etruria-geo ETRUSCAN fail
# 723 etruria-geo B.C. fail
# 723 etruria-geo LUNA hit
# 724 euboea-geo TELETHRIUS fail
# 725 euboea-geo CHALCTS. fail
# 726 euboea-geo CEREUS fail
# 726 euboea-geo DIUM hit
# 727 euesperidae-geo HESPERIDAE fail
# 728 eulaeus-geo ULAI fail
# 729 euphrates-geo PROMONTORIUM CHALDONE fail
# 729 euripus-geo CHALCIS hit
# 730 europa-geo B.C. fail
# 731 europa-geo B.C. fail
# 732 eutretus-geo EUTIRESIS. fail
# 733 euxinus-pontus-geo MAEOTIS fail
# 734 euxinus-pontus-geo MARE EUXINUM fail
# 734 euxinus-pontus-geo PHASIS hit
# 735 euxinus-pontus-geo TOMI fail
# 736 evenus-geo LYCORMAS fail
# 736 ezion-geber-geo BERENICE hit
# 736 fenni-geo SITONES hit
# 737 ferentinum-geo02 B.C. fail
# 738 fidenae-geo FIDENA fail
# 739 fiscellus-mons-geo APENNINUS fail
# 740 flanaticus-sinus-geo FLANATES fail
# 741 flenio-geo XII. fail
# 741 fortunatae-insulae-geo OCEANUS hit
# 742 fortunatae-insulae-geo SEBOSUS fail
# 743 forum-claudii-geo FOROCL. CENTRON. fail
# 744 forum-lepidi-geo REGIUM LEPIDUM. fail
# 745 forum-ligneum-geo BENEHARMUM. fail
# 746 forum-segusianorum-geo I fail
# 747 forum-voconii-geo FORUM JULII fail
# 747 frentani-geo ORTONA hit
# 748 frentani-geo M.P. fail
# 749 frentani-geo M.P. fail
# 750 frisii-geo FRRISIABONES. fail
# 751 fucinus-lacus-geo CUTILIAE LACUS. fail
# 752 fucinus-lacus-geo ANGITIA fail
# 753 fundi-geo LACUS FUNDANUS fail
# 754 furconium-geo IVESTINI. fail
# 755 gabalene-geo GEBALENE. fail
# 756 gabii-geo VIA GABINA fail
# 757 gabrantovici-geo PETUARII fail
# 758 gades-geo AUGUSTA URBS JULIA GADITANA fail
# 759 gaditanum-fretum-geo ATLANTICUIM MARE fail
# 760 gaetulia-geo GARAMIANTES fail
# 760 galactophagi-geo HIPPEMOLGI hit
# 761 galaria-geo GALATINI fail
# 762 galatia-geo AXYLOS fail
# 763 galatia-geo TAVIA fail
# 764 galava-geo CLANOVENTUM. fail
# 765 galindae-geo GOLTHES fail
# 766 gallaecia-geo CALLAÎCI fail
# 767 gallaecia-geo LIMIUS fail
# 768 gallaecia-geo NELUS fail
# 769 gallaecia-geo CALEM fail
# 770 gallaecia-geo BURBIDA fail
# 771 gallia-cisalpina-geo APENNINUS. fail
# 771 gallia-cisalpina-geo ATHESIS hit
# 772 gallia-cisalpina-geo CULICONES fail
# 773 gallia-cisalpina-geo FUNDUS fail
# 774 gallia-transalpina-geo CELTICE. fail
# 775 gallia-transalpina-geo ASPALUCA fail
# 776 gallia-transalpina-geo ALPES COTTIAE. fail
# 777 gallia-transalpina-geo FLEVO fail
# 778 gallia-transalpina-geo CEBENNA fail
# 779 gallia-transalpina-geo AQUITANI. fail
# 780 gallia-transalpina-geo CASTELLUM MORINORUM. fail
# 781 gallia-transalpina-geo ADUATUCA fail
# 782 gallia-transalpina-geo PARISII. fail
# 782 gallia-transalpina-geo AQUITANIA hit
# 783 gallia-transalpina-geo AMBALRRI. fail
# 784 gallia-transalpina-geo MANDUBII fail
# 784 gallia-transalpina-geo NITIOBRIGES hit
# 785 gallia-transalpina-geo BOIL fail
# 786 gallia-transalpina-geo NANNETES fail
# 787 gallia-transalpina-geo AMBILIATES fail
# 788 gallia-transalpina-geo PARISH fail
# 789 gallia-transalpina-geo COLONIA AGRIPPINENSIS. fail
# 790 gallicus-sinus-geo GALLTA. fail
# 791 gangas-geo ZYGACTES fail
# 792 garama-geo GARIAMANTES. fail
# 793 garamantes-geo GARAMANTICA PHARANX fail
# 794 garamantes-geo MONS ATER fail
# 794 garamantes-geo ATARANTES hit
# 795 garganus-geo MATINUS fail
# 796 garganus-geo AGASUS PORTUS fail
# 797 garites-geo B. C fail
# 798 gasorus-geo GRAERO fail
# 799 gaulanitis-geo GOLAN. fail
# 800 gaza-geo A. U. C. fail
# 801 gela-geo GELON fail
# 802 gela-geo CAMPI GELOI fail
# 803 gela-geo AESCHYLUS fail
# 804 geloni-geo GELONUS fail
# 804 gemella-geo ACCI hit
# 805 geneva-geo GENEVENS. PROVINCIA fail
# 806 geneva-geo HELVETI. fail
# 806 gennesaret-geo PALAESTINA hit
# 807 genua-geo PORCOBERA fail
# 808 genua-geo FERITOR fail
# 809 genusus-geo GENESIS fail
# 810 geranthrae-geo GEPRONTHRAE. fail
# 811 gerasus-geo GRESIA. fail
# 812 germania-geo GALLIA fail
# 813 germania-geo HERCYNIA SILVA fail
# 814 germania-inferior-geo GALLIA fail
# 815 germania-superior-geo GALLIA fail
# 816 gerontis-arx-geo CAEPIONIS TURRIS. fail
# 817 gerrhus-geo BUGES fail
# 818 gerrunium-geo GERTUS fail
# 819 gesocribate-geo BRIVATES. fail
# 820 gessorienses-geo AESONENSIS fail
# 821 gihon-geo JERIJSALEM. fail
# 822 giligammae-geo ADYRMACHIDAE fail
# 822 gindarus-geo CYRRHESTICA hit
# 823 glannibanta-geo CLANOVENTUM. fail
# 824 glanum-geo SEX. L. M. IVLIEI C. F. PARENTIBVS. SVEIS. fail
# 825 gonnus-geo LYCOSTOMIUM fail
# 826 gothi-geo RUGII. fail
# 827 graecia-geo NAME. fail
# 828 graecia-geo SITUATION fail
# 829 graecia-geo AEGAEUM MARE fail
# 830 graecia-geo CONFIGURATION OF THE SURFACE. fail
# 831 graecia-geo RIVERS AND LAKES. fail
# 831 graecia-geo BOEOTIA hit
# 832 graecia-geo GENERAL REMARKS UPON GRECIAN TOPOGRAPHY. fail
# 833 graecia-geo CHIEF PRODUCTIONS. fail
# 834 graecia-geo CLIMATE. fail
# 835 graecia-geo VOLCANIC CHANGES. fail
# 836 graecia-geo MODERN WORKS. fail
# 837 graecia-geo DESHAYES fail
# 838 graecia-geo SPON fail
# 839 graecia-geo STUART. fail
# 840 graecia-geo SIBTHORP fail
# 841 graecia-geo POUQUEVILLE fail
# 842 graecia-geo FRENCH COMMISSION fail
# 843 graecia-geo CURTIUS fail
# 844 graecia-geo MANNERT fail
# 845 gramatum-geo EPAMANDURUM fail
# 845 grinnes-geo DUODECIMUM hit
# 846 griselum-geo XI. fail
# 847 gruil-geo GAILAECIA. fail
# 848 grunaei-geo SCYTIA. fail
# 849 habessus-geo ANTPHELLUS. fail
# 850 habitancum-geo MOGONT CAD fail
# 851 habitancum-geo DEO INVICTO fail
# 852 habitancum-geo ICO MAXI fail
# 853 hadrianopolis-geo02 JUSTINOPOLIS fail
# 854 hadrumetum-geo COL. CONCORDIA ULPIA TRAJANA AUGUSTA FRUGIFERA HADRUMETINA fail
# 855 haebrides-geo HEBUDES. fail
# 856 haliacmon-geo ASTRAEUS fail
# 856 haliartus-geo BOEOTIA hit
# 857 halieis-geo HALIA fail
# 858 hammanientes-geo AMANTES. fail
# 859 harenatio-geo ARENACUSM. fail
# 859 harma-geo-1 BOEOTIA hit
# 860 harpis-geo HARPII fail
# 861 hebraei-geo PALESTINA. fail
# 861 hedylium-geo BOEOTIA hit
# 862 helena-geo02 ILLIBERRIS. fail
# 863 helicon-geo HIPPOCRENE fail
# 864 helicon-geo LEIBETHRIUM fail
# 865 heliopolis-aegypti-geo BETH-SCHEMISCH fail
# 866 heliopolis-syriae-geo COL. JULIA AUGUSTA FELIX HELIOPOLIS. fail
# 867 hellespontus-geo SESTOS fail
# 867 helli-geo DODONA hit
# 868 helvetii-geo GALLIA fail
# 869 helvetii-geo GENIO VERBIG. fail
# 870 helvetii-geo GENIO PAGI. TIGOR. fail
# 871 helvetii-geo-7 GALLIA fail
# 872 helvetii-geo-7 COLONIA EQUESTRIS fail
# 873 helvetii-geo-7 GALLIA fail
# 873 hephaestia-geo02 MELITA hit
# 874 hephaestiae-insulae-geo AEOLIAE INSULAE. fail
# 874 heptanomis-geo APHRODITOPOLIS hit
# 875 heptanomis-geo A. D. fail
# 876 heracleia-geo04 ZEUXIS. fail
# 877 herbita-geo B.C. fail
# 878 herculis-arenae-geo VELPI M. fail
# 879 herculis-geo-columnae-1 ONOBA fail
# 880 herculis-geo-columnae-3 ERYTHRAEUM MARE fail
# 881 herculis-insula-geo CARSTHAGO NOVA fail
# 882 herculis-monoeci-portus-geo MONOECUS. fail
# 882 hercyna-geo BOEOTIA hit
# 883 herdonea-geo ARDONEAE fail
# 884 hermaeum-geo-prom02-1 MERCURII PROM. fail
# 884 hermione-geo HALIEIS hit
# 884 hernici-geo FERENTINUM hit
# 885 hernici-geo COSAS fail
# 886 herodeium-geo-1 BETHACCAREM fail
# 886 heroopolites-sinus-geo HEROOPOLIS hit
# 887 herpeditani-geo MAUIETANIA fail
# 888 hicesia-geo AEOLIARE INSULAE. fail
# 889 hiera-geo-2 AEOLIAE INSULAE. fail
# 890 hierapolis-geo02 BAMBYCE fail
# 891 hilleviones-geo GERMANIA.) fail
# 892 hinnom-geo JERUSALEM:. fail
# 893 hippo-geo NOVA. fail
# 894 hippo-diarrhytus-geo CANDIDUM PR. fail
# 895 hippo-regius-geo UBUS fail
# 896 hipponiates-sinus-geo SINUS TERINAEUS fail
# 897 hippus-geo HIPPENE fail
# 898 hirpini-geo B.C. fail
# 898 hirpini-geo ABELLINUM hit
# 899 hirpini-geo AMSANCTUS fail
# 900 hirpini-geo VIA APPIA fail
# 901 hirros-geo HIEROS PORTUS fail
# 902 hispalis-geo HISPAL fail
# 903 hispania-geo SPAIN. fail
# 904 hispania-geo ANCIENT NAMES. fail
# 905 hispania-geo SPAN fail
# 905 hispania-geo CELTAE hit
# 906 hispania-geo TARTESSIS fail
# 906 hispania-geo IBERIA hit
# 907 hispania-geo SPAIN AS KNOWN TO THE GREEKS. fail
# 908 hispania-geo BEBREYCES fail
# 908 hispania-geo CIMMERII hit
# 908 hispania-geo TARTESSUS hit
# 909 hispania-geo HECATAEUS fail
# 910 hispania-geo CYNESII fail
# 911 hispania-geo EUDOXUS fail
# 912 hispania-geo HERODORUS fail
# 913 hispania-geo ERATOSTHIENES fail
# 914 hispania-geo CALBIUM fail
# 915 hispania-geo SPAIN AS KNOWN TO THE CARTHAGINIANS AND THE ROMANS. fail
# 916 hispania-geo TARTESSIS fail
# 917 hispania-geo CANTABRI fail
# 918 hispania-geo CELTIBERI. fail
# 919 hispania-geo CANTABRI fail
# 920 hispania-geo CAESAR AUGUSTA fail
# 921 hispania-geo POLITICAL DIVISIONS AND CONSTITUTION UNDER THE ROMANS. fail
# 922 hispania-geo HISPANIA CITERIOR fail
# 923 hispania-geo CARTHAGO NOVA fail
# 924 hispania-geo LUSITAIA fail
# 925 hispania-geo HISPANIA TARRACONENSIS fail
# 926 hispania-geo TARRACONENSIS fail
# 926 hispania-geo BAETICA hit
# 926 hispania-geo BAETICA hit
# 927 hispania-geo DESCRIPTIVE GEOGRAPHY FOR THE TIME OF THE ROMAN EMPIRE. fail
# 928 hispania-geo ALMOST fail
# 929 hispania-geo PR. NERIUM fail
# 930 hispania-geo POLYBIUS. fail
# 931 hispania-geo COAST FROM SW. TO NE. fail
# 932 hispania-geo ON THE BORDERS OF BAETICA AND LUSITANIA--SE. TO NW. fail
# 933 hispania-geo N. COAST fail
# 934 hispania-geo AT THE FOOT OF THE PYRENEES fail
# 935 hispania-geo IN THE CENTRE OF SPAIN. fail
# 936 hispania-geo PR. SACRUM fail
# 937 hispania-geo MARE INTERNUM fail
# 938 hispania-geo PYRENES PROM. fail
# 939 hispania-geo MALAGA fail
# 940 hispania-geo JUNONIS PR. fail
# 941 hispania-geo BARBARIUM PR. fail
# 942 hispania-geo PR. LUNAE fail
# 943 hispania-geo LUNAR fail
# 944 hispania-geo CELTICUM fail
# 945 hispania-geo CORU fail
# 945 hispania-geo BALEARES hit
# 946 hispania-geo VINDIUS M. fail
# 947 hispania-geo HERMINIUS M. fail
# 947 hispania-geo ASTURES hit
# 948 hispania-geo TARTESSIS fail
# 948 hispania-geo GALLAECIA hit
# 949 hispania-geo CLIMATE AND PRODUCTIONS. fail
# 949 hispania-geo BAETICA hit
# 950 hispania-geo POPULATION. fail
# 951 hispania-geo CELTIBERI fail
# 952 hispania-geo TURDETANIA. fail
# 953 hispania-geo HISPANORUM fail
# 954 hispanum-mare-geo MARE IBERICUM fail
# 954 hoplites-geo BOEOTIA hit
# 955 horca-geo ORCA. fail
# 956 hormanus-geo OMANITAE. fail
# 957 horrea-geo HORREA IMP. fail
# 958 horreum-margi-geo XIV fail
# 959 hunni-geo AUTHORITIES. fail
# 960 hunni-geo HUNS OF AMMIANUS. fail
# 961 hunni-geo HUNS OF PRISCUS. fail
# 962 hunni-geo TRADITIONARY VIEW OF ATTILA'S POWER AND CHARACTER. fail
# 963 hunni-geo POPULATIONS AKIN TO THE HUNS UNDER OTHER NAMES. fail
# 964 hunni-geo THE HUNS ETHNOLOGICALLY MEMBERS OF THE TURK FAMILY. fail
# 965 hunni-geo EARLY EUROPEAN HISTORY OF THE POPULATIONS AKIN TO THE HUNS. fail
# 966 hunni-geo-1 THE ACATZIRI. fail
# 967 hunni-geo-1 WHITE HUNS fail
# 968 hunni-geo-1 CHIONITAE. fail
# 969 hunni-geo-1 RELATIONS OF THE HUNNI TO THE HUN-JO CHINESE HISTORY. fail
# 970 hybla-geo-2 MEGARA HYBLAEA. fail
# 971 hybla-geo-3 HERA fail
# 972 hydruntum-geo BRUNDUSIUM. fail
# 973 hyle-geo-2 HYAEI fail
# 973 hylica-lacus-geo BOEOTIA hit
# 973 hypatus-mons-geo BOEOTIA hit
# 973 hyperborei-geo ARGIPPAEI hit
# 974 hyperborei-montes-geo RHIPAEX MONTES. fail
# 975 hyperboreus-oceanus-geo SEPTENTRIONALIS OCEANUS. fail
# 975 hyphanteium-geo BOEOTIA hit
# 976 hyrcania-geo CARTA fail
# 976 jabbok-geo AMMONITAE hit
# 976 jacca-geo JACCETANI hit
# 977 jaccetani-geo JACCETANIA fail
# 978 iadera-geo DIODORA. fail
# 979 iamissa-geo THAMESIS. fail
# 980 iapodes-geo IAPYDIA fail
# 981 iapodes-geo MONS ALBIUS fail
# 982 iapodes-geo AVENDONE fail
# 983 iapodes-geo EPIDOTIUM fail
# 984 iapygia-geo IAPYGES fail
# 985 iapygium-promontorium-geo PROMONTORIUM SALENTINUM fail
# 986 iaspis-geo CONTESTANIA. fail
# 987 iatinum-geo FIXTUINUM fail
# 988 iatrus-geo IANTRUS fail
# 989 jaxartes-geo ALEXANDREIA ULTIMA fail
# 990 jaxartes-geo COMEDI fail
# 991 jaxartes-geo A. D. fail
# 992 jazyges-geo IAZYGES METANASTAE fail
# 993 jazyges-geo A. D fail
# 994 iban-geo ARTEMITA BUANA. fail
# 995 ibera-geo MUN. HIBERA JULIA fail
# 996 iberia-geo MOSCHICHI MONTES fail
# 997 iberia-geo IBERI fail
# 998 iberia-geo PHARASMANES. fail
# 999 iberia-geo A. D fail
# 1000 iberia-geo IBERIAN GATES fail
# 1001 iberus-geo GALLICUS fail
# 1002 icarium-mare-geo ICARUS  fail
# 1003 icarus-geo ISTI fail
# 1004 icarusa-geo HIEROS PORTUS fail
# 1005 icaunus-geo DEAR ICAVSI. fail
# 1006 iccius-portus-geo ITIUS. fail
# 1007 ichthyophagi-geo TROGLODYTES. fail
# 1008 icorigium-geo EGGOIGIUM. fail
# 1009 idubeda-geo SALTUS MANLIANUS fail
# 1010 idumaea-geo NABATHAEI fail
# 1011 jebus-geo JERUSALAEM. fail
# 1011 ierne-geo HIBERNIA hit
# 1012 ierne-geo BELGAE OF BRITANNIA. fail
# 1013 jerusalem-geo NAMES. fail
# 1014 jerusalem-geo GENERAL SITE. fail
# 1015 jerusalem-geo WALLS. fail
# 1016 jerusalem-geo THE TEMPLE MOUNT. fail
# 1017 jerusalem-geo HISTORY. fail
# 1018 jerusalem-geo IMP. CAES. TRAIAN. HADRIANVS. AVG. fail
# 1019 jerusalem-geo THE MODERN CITY. fail
# 1020 jerusalem-geo ENVIRONS. fail
# 1021 iguvium-geo IKVVINI fail
# 1021 ilaraugatae-geo HISPANIA hit
# 1022 ilattia-geo ELATUS fail
# 1023 ilercaones-geo EDETANIA fail
# 1024 ilergetes-geo GALLICUS fail
# 1025 ilergetes-geo BORTINAE fail
# 1026 ilipula-geo-1 LAUS fail
# 1027 ilipula-geo-2 MINOR fail
# 1027 illiberis-geo02 CENTURIONES hit
# 1028 illyricum-geo ILLYRIS fail
# 1029 illyricum-geo ILLYRIS BARBARA fail
# 1030 illyricum-geo LIBURNIA fail
# 1031 illyricum-geo ILLYRIS GRAECA fail
# 1032 illyricum-geo LIBURNIDES. fail
# 1033 illyricum-geo ALBANOPOLIS fail
# 1034 illyricum-geo B.C. fail
# 1034 illyricum-geo DALMATIA hit
# 1035 illyricum-geo SCARDONA fail
# 1036 ilorci-geo ELOCROCA. fail
# 1037 iluro-geo BENEHARMUM. fail
# 1038 iluro-geo02-2 LAEÊTANI. fail
# 1039 ilva-geo AETHALIA fail
# 1040 ilvates-geo ELEATES fail
# 1041 imaus-geo BYLTAE fail
# 1042 inachus-geo-2 ARGOS AMPHILOCH. fail
# 1043 indaprathae-geo IBIERINGAE. fail
# 1044 india-geo B.C. fail
# 1044 india-geo INDUS hit
# 1045 india-geo INDO-SCYTHIA. fail
# 1046 india-geo INDI fail
# 1047 indicus-oceanus-geo SINUS PERIMULICITS fail
# 1048 indigetes-geo POMPEII TROPAEA. fail
# 1049 indoscythia-geo A.D.. fail
# 1050 ingaevones-geo HELLEV110NES. fail
# 1051 interamna-geo-1 INTERAMNA LIRINAS. fail
# 1052 internum-mare-geo MARE INTERNUM fail
# 1053 inui-castrum-geo CASTRUM INUL. fail
# 1054 iolcus-geo JASON fail
# 1054 ionia-geo PHOCAEA hit
# 1055 joppa-geo JAPHO fail
# 1056 jotapata-geo ARIBELA fail
# 1057 jotape-geo LAERTIC. fail
# 1058 isara-geo-3 LURA. fail
# 1059 isarus-geo ILARUS. fail
# 1060 isca-geo MURIDUNUM. fail
# 1061 isca-geo-1 UXELA fail
# 1062 isca-geo-2 ISCA LEGIONIS fail
# 1063 isca-geo-2 PRAEPOSITUS LEGIONIS II. AUGUST. RUTUPIS. fail
# 1064 isca-geo-2 DIIS MAN1BVS TADIA VELLAVIVS. VIXIT ANNOS SEXAGINTA QVINQVE. ET TADIVS EXUPERTVS FILIVS VIXIT ANNOS TRIGINTA SEPTEM. DEFVNTVS fail
# 1065 ischalis-geo ISCA DUMNONIORUM. fail
# 1066 issachar-geo PALARSTINA. fail
# 1066 issedones-geo BUDINI hit
# 1067 issus-geo CALYCADNITS fail
# 1068 issus-geo CASTABALITM fail
# 1069 issus-geo AMANUIDES PYLAE fail
# 1070 istria-geo PROMONTORIUM POLATICUM fail
# 1071 isturgi-geo IPASTURGI TRIUMPHALE fail
# 1072 isus-geo L. C. fail
# 1073 italia-geo NAME. fail
# 1074 italia-geo B.C. fail
# 1075 italia-geo HISRPANIA. fail
# 1076 italia-geo BOUNDARIES AND PHYSICAL GEOGRAPHY. fail
# 1077 italia-geo APENNINUS. fail
# 1078 italia-geo APENNINUS fail
# 1079 italia-geo NORTHERN ITALY. fail
# 1080 italia-geo NORTHERN ITALY fail
# 1081 italia-geo CENTRAL ITALY. fail
# 1081 italia-geo ETRURIA hit
# 1082 italia-geo SOUTHERN ITALY fail
# 1082 italia-geo APULIA hit
# 1083 italia-geo CLIMATE AND NATURAL PRODUCTIONS. fail
# 1084 italia-geo IV. RIVERS fail
# 1085 italia-geo VUTLTURNUS fail
# 1086 italia-geo MONS CIMINUS fail
# 1087 italia-geo ETHNOGRAPHY OF ANCIENT ITALY. fail
# 1088 italia-geo OENOTRIANS fail
# 1089 italia-geo B.C. [CAMPANIA.] fail
# 1090 italia-geo LIGURIANS fail
# 1091 italia-geo ISTRIANS fail
# 1092 italia-geo HISTORY. fail
# 1093 italia-geo B.C. fail
# 1094 italia-geo B.C. fail
# 1095 italia-geo AEMILIA fail
# 1096 italia-geo POPULATION OF ITALY UNDER THE ROMANS. fail
# 1097 italia-geo AUTHORITIES. fail
# 1097 italia-geo ABELLINUM hit
# 1098 italia-geo JULIA AUGUSTA. fail
# 1099 itanus-geo LFUCGE fail
# 1100 ithaca-geo NERITOS fail
# 1101 itucci-geo02 VIRTUS JULIA fail
# 1102 julia-joza-geo JULIA TRADUCTA fail
# 1103 junonia-insula-geo FORTUNATAE INS. fail
# 1104 jura-geo HELVETII  fail
# 1104 justiniana-geo CARTHAGO hit
# 1105 kadesh-geo ENMISHPAT fail
# 1106 kirjath-geo-1 KIRJATHAIM fail
# 1107 kirjath-geo-2 KIRJATH-ARBA fail
# 1108 kirjath-geo-3 KIRJATH-BAAL. fail
# 1109 kirjath-geo-4 KIRJATH-HUZOTH fail
# 1110 kirjath-geo-5 KIRJATH-JEARIM fail
# 1111 kirjath-geo-6 KIRJATH-SEPHER fail
# 1112 kirjath-geo-6 KIRHERESITH fail
# 1113 labeatis-lacus-geo LABEATAE. fail
# 1114 lacetani-geo JACETANI fail
# 1115 lacinia-geo IAPYDIA. fail
# 1116 lacinium-geo CROTONA. fail
# 1117 lacippo-geo LACIPO fail
# 1118 lacobriga-geo LUSITANIA; 2. VACCAEI. fail
# 1119 laconia-geo NAME. fail
# 1120 laconia-geo LACONICA fail
# 1121 laconia-geo GENERAL DESCRIPTION OF THE COUNTRY. fail
# 1122 laconia-geo MOUNTAINS fail
# 1123 laconia-geo MOUNT TAYGETUS fail
# 1124 laconia-geo PENTEDACTYLUM fail
# 1125 laconia-geo THERAS fail
# 1126 laconia-geo MOUNT PARNON fail
# 1127 laconia-geo BOMYCAS fail
# 1128 laconia-geo HISTORY fail
# 1129 laconia-geo TOWNS. fail
# 1129 laconia-geo SPARTA hit
# 1130 laconia-geo BELEMLNA. fail
# 1131 laconia-geo SCIRUS fail
# 1131 laconia-geo ACRIAE hit
# 1131 laconia-geo HYPSI hit
# 1131 laconimurgi-geo CELTICA hit
# 1132 lacringi-geo ASTINGI fail
# 1133 laeaetani-geo LUNARIUM PR. fail
# 1134 laestrygones-geo LAESTRYGONII CAMPI fail
# 1135 laletani-geo LAEÊTANI. fail
# 1136 lamasba-geo TAMUGADI. fail
# 1137 lambese-geo LAMBAESA fail
# 1138 lametini-geo LAMETUS fail
# 1139 lamia-geo PHALARA fail
# 1140 lance-geo LANCIATUM fail
# 1141 laodiceia-geo02 MARSYAS CAMPUS. fail
# 1142 lapathus-geo02 LAPETHIA fail
# 1142 laphystium-geo BOEOTIA hit
# 1143 lares-geo LARIBUS fail
# 1144 larinum-geo LADINOD fail
# 1145 larissa-geo-2 LARISSA CREMASTE fail
# 1146 larius-lacus-geo LACUS COMACINUS fail
# 1147 larnum-geo LAEÊTANI fail
# 1148 lartolaeaetae-geo LAEÊTANI. fail
# 1149 latara-geo LEDUTS. fail
# 1150 lathon-geo FLUVIUS LETHON fail
# 1151 latium-geo NAME. fail
# 1152 latium-geo LATINI fail
# 1153 latium-geo EXTENT AND BOUNDARIES. fail
# 1154 latium-geo PHYSICAL GEOGRAPHY. fail
# 1155 latium-geo HISTORY. fail
# 1156 latium-geo POLITICAL AND RELIGIOUS INSTITUTIONS. fail
# 1157 latium-geo TOPOGRAPHY. fail
# 1158 latium-geo NYMPHIAEUS fail
# 1159 latium-geo MONS ALGIDUS fail
# 1159 latium-geo ANTEMNAE hit
# 1159 lavinium-geo LATIUM hit
# 1160 lavinium-geo LAURO-LAVINIUM fail
# 1161 laus-pompeia-geo LAUS fail
# 1162 leanites-sinus-geo HAVILAH fail
# 1163 lebecii-geo LIBICI. fail
# 1164 ledus-geo LAEÊTANI. fail
# 1165 legio-vii-geo GALBIANA fail
# 1166 lehi-geo RAMATHLEHI fail
# 1167 leinum-geo LIANUM fail
# 1168 lemnos-geo HYPSIPYLE. fail
# 1169 lemnos-geo HEPHAESTIAS fail
# 1170 lemovices-geo ARMORICAE CIVITATES. fail
# 1171 leontes-geo CANIS fail
# 1172 leontini-geo LEONTINUS CAMPUS fail
# 1173 leontopolis-geo NICEPIHORIUM. fail
# 1174 lepontii-geo ALPES LEPONTIAE fail
# 1175 leptis-geo PARVA fail
# 1176 leptis-magna-geo HERMAEUM fail
# 1177 leptis-geo-magna-2 NEW CITY fail
# 1178 lesbos-geo ASSOS fail
# 1179 lesbos-geo ERESSUS. fail
# 1180 leucarum-geo MURIDUNUM. fail
# 1181 leucas-geo02 B.C. fail
# 1182 leucas-geo02 PHARA fail
# 1183 leucas-geo02 LEUCATAS fail
# 1184 leucimna-geo COROYRA fail
# 1185 libanus-mons-geo LEBANON fail
# 1186 libethra-geo CALLIPEUCE fail
# 1187 libnath-geo LACHISIH fail
# 1187 libnius-geo VENNICNII hit
# 1188 libui-geo LIBICI. fail
# 1189 liburni-geo LIBURNIA fail
# 1190 liburni-geo SCARDONA fail
# 1191 libya-geo A.D. fail
# 1191 libya-geo AEGYPTUS hit
# 1192 libya-geo B.C. fail
# 1193 libya-geo A. D. fail
# 1194 libya-geo A.D. fail
# 1195 libya-geo A. D. fail
# 1195 libya-geo AFRICA hit
# 1196 libya-geo GAETULI fail
# 1197 libyci-montes-geo OASIS. fail
# 1198 ligures-baebiani-et-corneliani-geo HIRPIN fail
# 1199 liguria-geo B.C. fail
# 1200 liguria-geo FRINIATES fail
# 1201 liguria-geo ALPES COTTIAE fail
# 1202 liguria-geo FRINIATES fail
# 1203 liguria-geo PORTUS MAURICI fail
# 1204 liguria-geo TAVIA fail
# 1205 liguria-geo VALENTINUM fail
# 1205 liguria-geo GENUA hit
# 1206 ligusticum-mare-geo LIGUSTICUS SINUS fail
# 1207 limenae-geo LIMNOPOLIS fail
# 1208 limites-romani-geo LIMES fail
# 1209 lintomagus-geo LUTTOAIAGUS. fail
# 1210 lipara-geo AEOLIAE INSULAE fail
# 1211 lipara-geo VULCANI INSULA fail
# 1212 liris-geo LUCUS MARICAE fail
# 1213 listron-geo ALISTRUS fail
# 1214 liternum-geo LINTERNUM fail
# 1215 lobetani-geo CELTIBERI fail
# 1216 locri-geo02 ZALEUCUS fail
# 1217 locri-geo02 CROTONA. fail
# 1218 locri-geo02 L. C. fail
# 1219 locris-geo-1 OPUNTII fail
# 1220 locris-geo-1 ALPENUS fail
# 1221 locris-geo-2 LOCRI OZOLAE fail
# 1222 locris-geo-2 AMPIISSA fail
# 1223 logia-geo VINDERIUS fail
# 1224 londobris-geo LUNARIUM fail
# 1224 lophis-geo BOEOTIA hit
# 1225 lossonus-geo OLOOSOON. fail
# 1226 lucania-geo HELES fail
# 1227 lucania-geo OENOTRIDES. fail
# 1228 lucania-geo ELEA fail
# 1229 lucania-geo VOLCENTUM fail
# 1230 luceria-geo LOVCERI fail
# 1231 lucrinus-lacus-geo JULIUS PORTUS fail
# 1232 lucus-angitiae-geo ANGITIA fail
# 1233 lucus-geo-augusti02 BRACARA fail
# 1233 lugdunum-geo AQUITANIA hit
# 1234 lugdunum-geo GALLIA TRANS. fail
# 1235 lugdunum-geo02 CONVENANE. fail
# 1236 lusitania-geo SACRUM PR. fail
# 1237 lusitania-geo HISANIA fail
# 1238 lusitania-geo MONS HERMINIUS fail
# 1239 lusitania-geo LUSITANI fail
# 1240 lusitania-geo VIRIATHUS fail
# 1241 lusitania-geo LUSITANIA PROVINCIA fail
# 1242 lusitania-geo EMERITA fail
# 1243 lusitania-geo AD VII ARAS fail
# 1244 lutetia-parisiorum-geo A. D. fail
# 1244 lycaonia-geo ICONIUM hit
# 1245 lycaonia-geo AMYNTAS fail
# 1246 lychnidus-geo ACHRIDA fail
# 1246 lycia-geo DAEDALA hit
# 1246 lycia-geo XANTHUS hit
# 1247 lycus-geo-4 CHONAS. fail
# 1248 lycus-geo04 LAGOUS fail
# 1249 lydia-geo MESSOGIS fail
# 1250 lyncestis-geo LYNCESTAE fail
# ...
# 1879 roma-geo TEMPLE OF FORS FORTUNA fail
# 1880 roma-geo NAUMACHIAE fail
# 1881 roma-geo HORTI GETAE fail
# 1882 roma-geo MCNS fail
# 1883 roma-geo HORTI DOMITIAE fail
# 1884 roma-geo TEMPLUM APOLLINIS fail
# 1885 roma-geo CIRCUS MAXIMUS fail
# 1886 roma-geo CIRCUS FLAMINIUS fail
# 1887 roma-geo CIRCUS AGONALIS fail
# 1888 roma-geo CAIANUM fail
# 1889 roma-geo MAXENTIUS fail
# 1890 roma-geo CIRCUS HELIOGABALI fail
# 1891 roma-geo THEATRUM POMPEII fail
# 1892 roma-geo THEATRE OF BALBUS fail
# 1893 roma-geo THEATRUM MARCELLI fail
# 1894 roma-geo ODEUM fail
# 1895 roma-geo AMPHITHEATRE OF STATILIUS TAURUS fail
# 1896 roma-geo AMPHITHEATRUM CASTRENSE fail
# 1897 roma-geo THERMAE AGRIPPAE fail
# 1898 roma-geo THERMAE TITI fail
# 1899 roma-geo THERMAE COMMODIANAE fail
# 1900 roma-geo THERMAE ANTONINIANAE fail
# 1901 roma-geo THERMAE DIOCLETIANAE. fail
# 1902 roma-geo THERMAE SURANAE ET DECIANAE fail
# 1903 roma-geo PONS SUBLICIUS fail
# 1904 roma-geo INTER DUOS PONTES. fail
# 1905 roma-geo PONS CESTIUS fail
# 1906 roma-geo PONS AELIUS fail
# 1907 roma-geo PONS AURELIUS fail
# 1908 roma-geo AQUAEDUCTUS. fail
# 1909 roma-geo AQUA APPIA fail
# 1910 roma-geo ANIO VETUS fail
# 1911 roma-geo AQUA MARCIA fail
# 1912 roma-geo AQUA TEPULA fail
# 1913 roma-geo AQUA JULIA fail
# 1914 roma-geo AQUA VIRGO fail
# 1915 roma-geo AQUA ALSIETINA fail
# 1916 roma-geo AQUA CLAUDIA fail
# 1917 roma-geo ANIO NOVUS fail
# 1918 roma-geo AQUA TRAJANA fail
# 1919 roma-geo AQUA ALEXANDRINA fail
# 1920 roma-geo AQUA SEVERIANA fail
# 1921 roma-geo AQUA ANTONINIANA fail
# 1922 roma-geo VIAE fail
# 1923 roma-geo MONUMENTUM ANCYRANUM fail
# 1924 roma-geo NOTITIA. fail
# 1925 roma-geo REGIONARII fail
# 1926 roma-geo ANONYMUS EINSIEDLENSIS. fail
# 1927 roma-geo MIRABILIA ROMAE fail
# 1928 roma-geo POGGIO fail
# 1929 ruscino-geo COL. RUS. LEG. VI. fail
# 1930 ruspe-geo CAPUT VADORUM fail
# 1931 ruticlei-geo RUGII. fail
# 1931 saba-geo ARABIA hit
# 1932 sabatia-vada-geo VADA SABATIA. fail
# 1933 sabatinus-lacus-geo SABATE fail
# 1934 sabbata-geo VADA SABATIA. fail
# 1935 sabini-geo APENNINUS. fail
# 1935 sabini-geo ABORIGINES hit
# 1936 sabini-geo MONS FISCELLUS fail
# 1937 sabini-geo F fail
# 1938 sabini-geo TREBULA MUTUSCA fail
# 1938 sabrata-geo ABROTONUM hit
# 1939 sacapene-geo SACASENE. fail
# 1940 sachalitae-geo SACHALITES SINUS fail
# 1941 sagaris-geo SINUS SAGARIUS. fail
# 1942 sagras-geo CROTONA. fail
# 1943 salamis-geo02 CYCHREIA fail
# 1944 salamis-geo02 BOCALIAS fail
# 1945 salamis-geo02 SILENIAE fail
# 1946 salamis-geo02 BUDORUM fail
# 1947 salapia-geo SALAPINA PALUS fail
# 1948 salassii-geo MAIRETANIA fail
# 1948 salentini-geo ALETIUM hit
# 1948 salernum-geo MARCINA hit
# 1949 saliocanus-geo STAIOCANUS. fail
# 1950 salmone-geo02 SAMONIUM PROMONTORIUM. fail
# 1951 salodurum-geo GANODUBUM fail
# 1952 salona-geo IADER fail
# 1953 salona-geo ASPALATHUM fail
# 1954 salsulae-geo LEUCATE fail
# 1954 salyes-geo DECIATES hit
# 1955 samamycii-geo SYRTICA. fail
# 1955 samara-geo FRUDIS hit
# 1956 samaria-geo02 SHOMRON fail
# 1957 samnium-geo GENERAL DESCRIPTION. fail
# 1958 samnium-geo MONS TABURNUS fail
# 1959 samnium-geo MONS VULTUR fail
# 1960 samnium-geo HISTORY. fail
# 1961 samnium-geo APUTLIA. fail
# 1962 samnium-geo TOPOGRAPHY. fail
# 1962 samnium-geo BOVIANUM hit
# 1963 samnium-geo AQUILONLIA fail
# 1963 samnium-geo MUCRAE hit
# 1964 samos-geo SAMTOTHRACIA fail
# 1965 samos-geo POLYORATES fail
# 1965 samothrace-geo CEPHALLENIA hit
# 1966 samulocenae-geo SUMLOCENNE fail
# 1967 saphar-geo SAPPHAR. fail
# 1968 sapis-geo SAPINIA TRIBUS fail
# 1969 sappharitae-geo SAPPHAR. fail
# 1970 saraceni-geo MIDIAN fail
# 1971 sardinia-geo GENERAL DESCRIPTION. fail
# 1972 sardinia-geo HISTORY. fail
# 1973 sardinia-geo S. C. fail
# 1974 sardinia-geo TOPOGRAPHY. fail
# 1975 sardinia-geo SACER FLUVIUS fail
# 1975 sardinia-geo NORA hit
# 1976 sardinia-geo NATURAL PRODUCTIONS fail
# 1977 sardoum-geo MARE HISPANUM fail
# 1978 sarepta-geo M. P. fail
# 1979 sarmatia-geo SARMATIAE fail
# 1980 sarmatia-geo VENEDI. fail
# 1981 sarmatia-geo RIVERS. fail
# 1982 sarmatia-geo MOUNTAINS. fail
# 1983 sarmatia-geo TOWNS. fail
# 1984 sarmatia-geo ETHNOLOGY. fail
# 1985 sarmatia-geo HISTORY. fail
# 1985 sarmatia-geo VANDALI hit
# 1986 sarmizegethusa-geo XIII. fail
# 1987 scarpona-geo IIII fail
# 1988 scenae-geo-2 SCENAE MANDRAE fail
# 1989 scenae-geo-3 SCENAE VETERANORUM fail
# 1990 scincomagus-geo OCELUSM. fail
# 1991 sciritis-geo SCIRUS fail
# 1992 scombrasia-geo SATURNI PROM. fail
# 1993 scotane-geo CLEFTOR fail
# 1994 scyllaeum-geo SCYLLA. fail
# 1994 scythia-geo EXAMPAEUS hit
# 1994 scythia-geo SAUROMATAE hit
# 1995 scythia-geo RELIGION fail
# 1996 scythia-geo REGIBUS BASTERNARUM ET RHOXOLANORUM FILIOS DACORUM . . . EREPTOS REMISIT . . . SCYTHARUM QUOQUE REGE A CHERSONESI QUAe EST ULTRA BORYSTHENEM OBSIDIONE SUMMOTO. fail
# 1996 scythia-geo HUNNI hit
# 1996 scythia-geo SARMATIA hit
# 1997 secerrae-geo SETERRAE fail
# 1997 seduni-geo NANTUATES hit
# 1998 segelocum-geo AGELOCUM fail
# 1999 segesama-geo SEGESAMO fail
# 2000 seleuceia-geo-1 AD BELUM fail
# 2001 selinus-geo02 THERMAE SELINUNTIAE fail
# 2002 sembritae-geo SEMBERRITAE fail
# 2003 sena-geo SENA GALLICA fail
# 2004 sena-geo02 SENA JULIA fail
# 2005 senones-geo MANDUBII fail
# 2005 setius-mons-geo BLASCON hit
# 2006 severi-murus-geo VALLUM. fail
# 2007 severus-mons-geo APENNINUS. fail
# 2008 shalisha-geo BAAL SHALISHA. fail
# 2009 sheba-geo SABAEA. fail
# 2010 shechem-geo NEAPOLIS II. fail
# 2011 sichem-geo NEAPOLIS II. fail
# 2012 sicilia-geo GENERAL DESCRIPTION. fail
# 2013 sicilia-geo FRETUM SICULUM fail
# 2014 sicilia-geo MOUNT ERYX fail
# 2015 sicilia-geo MONS NEBRODES fail
# 2016 sicilia-geo LEONTINUS fail
# 2017 sicilia-geo HISTORY. fail
# 2018 sicilia-geo SICELS fail
# 2019 sicilia-geo B.C. fail
# 2020 sicilia-geo B.C. fail
# 2021 sicilia-geo DIONYSIUS fail
# 2022 sicilia-geo TOPOGRAPHY. fail
# 2023 sicilia-geo XIPHONIAN PORT fail
# 2024 sicilia-geo ADRANUS fail
# 2024 sicilia-geo HIPPARIS hit
# 2025 sicilia-geo CRIMESSUS fail
# 2026 sicilia-geo ALABUS fail
# 2027 sicilia-geo LYSIMELIA PALUS fail
# 2027 sicilia-geo MESSANA hit
# 2028 sicilia-geo SCHERA fail
# 2029 sicilia-geo HYBLA MAJOR fail
# 2030 sicilia-geo TYRACINI fail
# 2031 sicyon-geo AEGIALI fail
# 2032 sicyon-geo EUPHRON. fail
# 2033 sicyon-geo B.C. 251. fail
# 2034 sicyon-geo GONUSSA fail
# 2034 sidon-geo PHOENICIA hit
# 2034 sidon-geo PHOENICIA hit
# 2035 sihor-geo-2 SHIHOR LIBNATH fail
# 2036 silvia-geo SALVIA fail
# 2037 simundu-geo TAROBANE. fail
# 2037 simyra-geo ELEUTHERUS hit
# 2038 sinti-geo SINTICE fail
# 2039 siris-geo B.C. fail
# 2040 solenta-geo OLYNTA INSULA. fail
# 2041 solis-fons-geo OASIS fail
# 2042 solis-promontorium-geo LAR fail
# 2043 somena-geo SIMENA. fail
# 2044 sontius-geo FLUVIUS FRIGIDUS. fail
# 2044 sordice-geo SALSULAE hit
# 2045 sparta-geo ALCMAN fail
# 2046 sparta-geo THERAPRN fail
# 2046 sphingium-geo BOEOTIA hit
# 2047 spina-geo SPINETICUM OSTIUM fail
# 2047 stabulum-geo CENTURIONES hit
# 2048 stagna-volcarum-geo FECYI JUGUM fail
# 2049 stentoris-lacus-geo STENTORIS PORTUS fail
# 2050 strongyle-geo AEOLIAE INSULAE. fail
# 2051 sublaqueum-geo SIMBRUINA STAGNA fail
# 2052 suche-geo SUCHIM fail
# 2053 suessiones-geo NONIODUNUM fail
# 2054 sulgas-geo GALLIA fail
# 2055 sulis-geo DARIORIGUM fail
# 2056 surae-geo SORAE. fail
# 2057 surrentinum-prom-geo MINERVAE PROM. fail
# 2058 susiana-geo ELAM fail
# 2059 syagros-promontorium-geo MOSCHA. fail
# 2060 symplegades-geo BOSPORUS fail
# 2061 syracusae-geo SITUATION. fail
# 2062 syracusae-geo EURYALUS. fail
# 2063 syracusae-geo PORTUS LACCEIUS fail
# 2064 syracusae-geo OLYMPIEUM fail
# 2065 syracusae-geo HISTORY. fail
# 2066 syracusae-geo DIONYSIUS fail
# 2067 syracusae-geo TOPOGRAPHY. fail
# 2068 syracusae-geo B.C. fail
# 2069 syracusae-geo ACHRADINA fail
# 2070 syracusae-geo PORTUS TROGILIORUM fail
# 2071 syracusae-geo TYCHA fail
# 2072 syracusae-geo EPIPOLAE fail
# 2073 syracusae-geo LABDALUM fail
# 2074 syria-geo SAMACHONITIS LACUS fail
# 2074 syria-geo ORONTES hit
# 2074 syria-geo PHOENICIA hit
# 2075 syria-geo THE COAST fail
# 2076 syria-geo B.C. fail
# 2077 syria-geo B.C. fail
# 2078 syria-geo REX ARETAS. fail
# 2079 syria-geo SYRIA PHOENICE fail
# 2080 syrieni-geo SYRASTRENE. fail
# 2081 taenarum-geo HARBOUR OF ACHILLES fail
# 2082 taenarum-geo TAENABUM fail
# 2083 talmis-geo A. D. fail
# 2083 tamyraces-sinus-geo CARCINA hit
# 2084 tanis-geo ZOAN fail
# 2085 taphiae-geo AMPHITRYON. fail
# 2086 taphros-geo TAURUS. fail
# 2087 tarbelli-geo COCOSSATES. fail
# 2088 tarentum-geo TARENTINUS SINUS fail
# 2089 tarnis-geo LESORA. fail
# 2090 tarracina-geo B. fail
# 2091 tarraga-geo TERRACHA fail
# 2091 taurica-chersonesus-geo CARCINA hit
# 2092 taurica-chersonesus-geo B.C. fail
# 2092 taurisci-geo NORICUM hit
# 2093 taurus-palus-geo FECYI JUGUM fail
# 2094 teanum-geo TEANUM APULUM fail
# 2095 teanum-geo02 TEANUM SIDICINUM fail
# 2096 tebenda-geo B. fail
# 2097 tecum-geo TIOHIS. fail
# 2098 tegea-geo02 TEGEATIS fail
# 2099 tegea-geo02 SYMBOLA fail
# 2100 tegea-geo02 PHEIDIPPIDES. fail
# 2101 teglicium-geo TEGULITIA fail
# 2101 temmices-geo BOEOTIA hit
# 2101 tenericus-campus-geo BOEOTIA hit
# 2102 tentyra-geo OMBOS fail
# 2102 terenuthis-geo NITRIAE hit
# 2103 tergeste-geo TERGESTINUS SINUS fail
# 2104 terina-geo SINUS TERINAEUS fail
# 2105 termantia-geo TLERMES. fail
# 2106 tesebarice-geo TROGLODYTAE. fail
# 2106 teumessus-geo BOEOTIA hit
# 2107 thabor-geo ATYBARIUM. fail
# 2108 thagulis-geo TAGULUS fail
# 2109 thebae-geo NO-AMMON fail
# 2110 thebae-geo MEMNON fail
# 2111 thebae-geo02 HISTORY. fail
# 2111 thebae-geo02 BOEOTIA hit
# 2112 thebae-geo02 L. C. fail
# 2113 thebae-geo02 TOPOGRAPHY. fail
# 2114 thebae-geo02 ELECTRAE fail
# 2115 thebae-geo02 AESCHYLUS. fail
# 2116 thebae-geo02 III. fail
# 2117 thebais-geo THEBAE AEGYPTI. fail
# 2118 theodosiopolis-geo APRI fail
# 2119 thermae-geo-1 THERMAE HIMERENSES fail
# 2120 thespiae-geo PRAXITELES. fail
# 2120 thessalia-geo OSSA hit
# 2121 thessalia-geo MAGNETES fail
# 2122 thessalia-geo-1 HESTIAEOTIS fail
# 2123 thessalia-geo-2 ELATEA fail
# 2123 thessalia-geo-3 PEIRESIAE hit
# 2124 thessalia-geo-4 PHTHIOTIS fail
# 2124 thessalia-geo-5 CERCINIUM hit
# 2125 thessalia-geo-6 DOLOPIA fail
# 2126 thessalia-geo-7 OETAEA fail
# 2127 thessalia-geo-7 MALIS fail
# 2128 thessalonica-geo-1 SITUATION. fail
# 2129 thessalonica-geo-2 NAME. fail
# 2130 thessalonica-geo-3 POLITICAL AND MILITARY HISTORY. fail
# 2131 thessalonica-geo-4 ECCLESIASTICAL HISTORY. fail
# 2132 thessalonica-geo-5 REMAINS OF ANTIQUITY. fail
# 2133 thessalonica-geo-6 AUTHORITIES. fail
# 2133 theuprosopon-geo PHOENICIA hit
# 2134 thospitis-geo LACUS THOSPITES fail
# 2135 thracia-geo NAME. fail
# 2136 thracia-geo EXTENT. fail
# 2137 thracia-geo PHYSICAL GEOGRAPHY fail
# 2138 thracia-geo ETHNOLOGY fail
# 2139 thracia-geo BENDIS fail
# 2140 thracia-geo HISTORY. fail
# 2141 thracia-geo B.C. fail
# 2141 thracia-geo BYZANTIUM hit
# 2142 thracia-geo CERSOBLEPTES fail
# 2143 thracia-geo ANTIGONUS GONATAS fail
# 2144 thracia-geo TOPOGRAPHY. fail
# 2145 thracius-bosporus-geo BOSPORUS. fail
# 2146 thurii-geo B.C. fail
# 2147 thurii-geo COPIAE fail
# 2147 thurium-geo BOEOTIA hit
# 2147 tiberias-mare-geo JORDANES hit
# 2147 tiberis-geo ROMA hit
# 2148 ticinus-geo LACUS VERBANUS fail
# 2149 tifernum-geo-1 TIFERNUM TIBIERINUM fail
# 2150 tifernum-geo-2 TIFERNUM METAURENSE fail
# 2151 tifernus-geo TIFEBNUS MONS fail
# 2151 tilphossa-fons-geo BOEOTIA hit
# 2151 tilphossium-geo BOEOTIA hit
# 2152 tilurium-geo TILURI PONS fail
# 2153 tinia-geo CLITUANUS fail
# 2154 tiristasis-geo DIOPEITHES fail
# 2155 tisaeum-geo TYSCA fail
# 2156 tisebarice-geo TESEBARICA. fail
# 2157 tolosa-geo B.C. 106 fail
# 2158 topiris-geo TOPIRUS fail
# 2159 toxandri-geo GALLIA TRANS. fail
# 2160 trachis-geo-2 PHOCICA fail
# 2161 traia-capita-geo TRIA CAPITA fail
# 2162 transducta-geo TRADUCTA fail
# 2163 trebula-geo02-1 TREBULA MUTUSCA fail
# 2164 trebula-geo02-2 TREBULA SUFFENAS fail
# 2165 trepontium-geo DECENNOVIUM fail
# 2166 tribulium-geo TRILURIUM fail
# 2167 tricornium-geo TRICORNIA CASTRA fail
# 2167 tripolis-geo PHOENICIA hit
# 2168 tripolitana-regio-geo SYRTICA. fail
# 2169 trivicum-geo VIAAPPIA. fail
# 2170 troas-geo SATNIOIS fail
# 2171 trocmi-geo GALATLA fail
# 2171 troja-geo ILIUM hit
# 2172 tronis-geo DAULTS fail
# 2173 tuder-geo TVTERE fail
# 2174 tugeni-geo HELVETU fail
# 2175 turnacum-geo DVRNACOS fail
# 2176 turoqua-geo TURAQUA fail
# 2177 turris-geo-1 TURRIS CAESARIS fail
# 2178 turris-geo-2 EUPHRANTA TURRIS. fail
# 2179 turris-geo-3 TURRIS HANNIBALIS fail
# 2180 turris-geo-4 TURRIS TAMALLENI fail
# 2181 tusculum-geo TVSCVL fail
# 2181 tylus-geo PHOENICIA hit
# 2182 tymphe-geo TYMPHAEI fail
# 2183 tyrrhenum-mare-geo MARE INFERUM fail
# 2183 tyrus-geo PHOENICIA hit
# 2183 tyrus-geo PHOENICIA hit
# 2183 tyrus-geo PHOENICIA hit
# 2184 tysia-geo TISIANUS. fail
# 2184 vahalis-geo BATAVI hit
# 2184 vallis-pennina-geo NANTUATES hit
# 2185 vallum-romanum-geo VALLUM fail
# 2186 vallum-romanum-geo CASTELLA fail
# 2187 vasatae-geo COSSIUM. fail
# 2188 vasates-geo COSSIUM. fail
# 2189 ubii-geo COLONIA AGRIPPINA fail
# 2190 ucetia-geo VCETIAE fail
# 2191 vegia-geo VEGIUM fail
# 2192 veii-geo A. U. C. fail
# 2192 velauni-geo NERUSII hit
# 2193 velinus-geo VELINI LACUS fail
# 2194 veneti-geo DARIORIGUM. fail
# 2195 venetia-geo TURRUS fail
# 2195 veneticae-insulae-geo VENETI hit
# 2195 veragri-geo NANTUATES hit
# 2195 verrucini-geo CAMATULLICI hit
# 2196 vestini-geo MONS FISCELLUS fail
# 2197 vestini-geo ATERNUM fail
# 2198 vesuvius-mons-geo VESEVUS fail
# 2199 ugernum-geo VGERNI fail
# 2200 via-geo-aemilia-1 M. P. fail
# 2201 via-geo-aemilia-1 M. P. fail
# 2202 via-geo-aemilia-2 M. P. fail
# 2203 via-geo-aemilia-2 M. P. fail
# 2204 via-geo-aemilia-3 M. P. fail
# 2205 via-geo-aemilia-3 M. P. fail
# 2206 via-geo-aemilia-4 M. P. fail
# 2207 via-geo-aemilia-5 M. P. fail
# 2208 via-geo-aemilia-6 M. P. fail
# 2209 via-geo-aemilia-7 M. P. fail
# 2210 via-amerina-geo M. P. fail
# 2211 via-amerina-geo M. P. fail
# 2212 via-geo-appia-1 M. P. fail
# 2213 via-geo-appia-1 M. P. fail
# 2214 via-geo-appia-1 CLIVUS VIRBII fail
# 2215 via-geo-appia-1 VIA ANTIATINA fail
# 2216 via-geo-appia-1 M. P. fail
# 2217 via-geo-appia-2 M. P. fail
# 2218 via-geo-appia-3 M. P. fail
# 2219 via-geo-appia-4 M. P. fail
# 2220 via-geo-appia-4 M. P. fail
# 2221 via-geo-appia-4 M. P. fail
# 2222 via-geo-appia-5 M. P. fail
# 2223 via-geo-appia-5 M. P. fail
# 2224 via-geo-appia-5 M. P. fail
# 2225 via-geo-appia-5 M. P. fail
# 2226 via-geo-appia-5 VIA HERCULIA fail
# 2227 via-geo-appia-5 M. P. fail
# 2228 via-aurelia-geo M. P. fail
# 2228 via-aurelia-geo LIGURIA hit
# 2229 via-aurelia-geo M. P. fail
# 2230 via-geo-aurelia-1 M. P. fail
# 2231 via-geo-aurelia-2 M. P. fail
# 2232 via-cassia-geo M. P. fail
# 2233 via-cassia-geo M. P. fail
# 2234 via-ciminia-geo CIMINUS MONS. fail
# 2235 via-clodia-geo M. P. fail
# 2236 via-clodia-geo M. P. fail
# 2237 via-egnatia-geo B.C. fail
# 2238 via-flaminia-geo M. P. fail
# 2239 via-flaminia-geo M. P. fail
# 2240 via-flaminia-geo M. P. fail
# 2241 via-flaminia-geo M. P. fail
# 2242 via-flaminia-geo M. P. fail
# 2243 via-labicana-geo M. P. fail
# 2244 via-latina-geo M. P. fail
# 2245 via-latina-geo M.P. fail
# 2246 via-latina-geo M.P. fail
# 2247 via-nomentana-geo NOMENTUM. fail
# 2248 via-praenestina-geo VIA GABINA fail
# 2249 via-praenestina-geo M. P. fail
# 2250 via-salaria-geo M. P. fail
# 2251 via-salaria-geo M. P. fail
# 2252 via-valeria-geo MONS IMEUS fail
# 2253 via-valeria-geo M. P. fail
# 2254 via-valeria-geo M. P. fail
# 2255 vicus-ambiatinus-geo AMBIATINUS. fail
# 2256 vicus-spacorum-geo SPACORUM VICUS. fail
# 2257 vidubia-geo TILE fail
# 2258 viducasses-geo ORDO CIVITATIS VIDVCAS. fail
# 2258 vienna-geo BERGINTRUM hit
# 2259 vigesimum-geo-1 DUODEOCIMUM fail
# 2260 viminacium-geo VII. fail
# 2260 vindelicia-geo ILARGUS hit
# 2260 vindelicia-geo BRIGANTII hit
# 2261 vindinum-geo SUININIUM. fail
# 2262 vindobala-geo I. fail
# 2263 vindonissa-geo XXI. fail
# 2264 vintium-geo CIVIT. VINT. fail
# 2265 virosidum-geo VI. fail
# 2266 ulpianum-geo-1 ULPIANA fail
# 2267 umbria-geo PISAURUS fail
# 2267 umbria-geo TREBA hit
# 2268 vocontii-geo DEA fail
# 2269 volaterrae-geo FELATHRI fail
# 2270 volcae-geo NARBO fail
# 2271 vorganium-geo OSISMII fail
# 2272 urbinum-geo-1 URBINUM HORTENSE fail
# 2273 urbinum-geo-2 URBINUM METAURENSE fail
# 2274 urgo-geo GORGONA. fail
# 2275 uria-geo HYRIUM. fail
# 2276 vulcaniae-insulae-geo AEOLIAEINSULAIE. fail
# 2277 uxellodunum-geo MANDUBII fail
# 2278 uxellodunum-geo02 I. fail
# 2279 zabe-geo BERZABDA. fail
# 2280 zacynthus-geo M. P. fail
# 2281 zarangi-geo DRANGAE. fail
# 2282 zephyrium-promontorium-geo LOCRI EPIZEPHYRII. fail
# 2283 zephyrium-geo02-5 D. fail
# 2284 ziguensis-mons-geo ZEUGITANA. fail
# pass 2 done 4916 250 21536 10418 xrefs 1135 2284

# %%
titles = {}
titlelen = {}

ethnics = {}
f = open('ethnics-list.txt')
for l in f:
    l = re.sub('^[\s0-9]+','',l)
    l = re.sub('\n','',l)
    ethnics[l] = 1
f.close()

print('ethnics done')

places = []
f2 = open('place-excepts.txt')
for l in f2:
    l = re.sub('^[\s0-9]+','',l)
    l = re.sub('\n','',l)
    if(not re.search('[A-Z]',l)):
        continue
    places.append(re.sub('\n','',l))

f2.close()

print('places done')

f = open('smithgeo-work.xml')

skipit = 0
hits = 0
for l in f:
    #if(not re.search('<p>',l)):
    #    continue

    l = re.sub('(<title>[A-Z][a-z]+),\s+([A-Z][a-z]+</title>)','\g<1></title>, <title>\g<2>',l)
    l = re.sub('<title>[^<]+</title>[,\s]+(p\.|pp\.|vol\.|[0-9]+)',' ',l)
    matchs = '<title>([A-Z][a-z][a-z][a-z][^<]+)</title>'
    while(re.search(matchs,l)):
        m = re.search(matchs,l)
        curabb = m[1]
#        if(curabb in ethnics):
 #           continue
        if(curabb in places or curabb in ethnics):
            skipit = skipit + 1
            l = re.sub(matchs,'',l,1)
            continue
        hits = hits + 1
        if(curabb in titles):
            titles[curabb] = titles[curabb] + 1
        else:
            titles[curabb] = 1
        l = re.sub(matchs,'',l,1)
    

f.close()
print(hits,skipit)
i = 4

outf = open('placestmp.txt','w')
for foo in titles:
    titlelen[foo] = len(foo)
    
#for foo in sorted(titles,key=titles.get,reverse=True):
for foo in sorted(titlelen,key=titlelen.get):

    if(foo in places):
        continue
    if(len(foo) > 28):
        continue
    if(re.search('(Untersuch|Settlements|Proceeding|Wört|Vorträg|Hebrew|Cyclop|Land of|Sons of|Rocky A|Ethnog|Penny|Ruin|Coins|Wallfahrt|Correspon|Genius|Museo|Archiv|Periplus|Notice|Tableaux|unter den Römern|Explor|Scient|Geschic|Ricerch|Zeitsch|Museum|Account|Handbuch|Economie|Atti|Architett|Acta|Years|Onomast|Comment|Liber|Histor|Mittel Italien|Deuteronomy|Nehem|Wanderu|Tour|Carta\s|Encycl|Descriz|Revu|^Southern$|^Northern$|Annali|Chronogr|Erdkunde|Sitten|Lexic|Rapport|Rosett|Bericht|Geolog|Monum|Medieval|Archaeol|Transact|Handboo|Architect|Greece\s+under|Notes|\s+et\s+|Guid|\s+und\s+|Vita|Symboli|Bibl\.|Forschung|Italian-Greek|geschicht|Dialekt|antica Città|Antich|Observa|Remembrancer|Ausland|Memori|Memoir|Vindic|Misc|Trav|Remains|\s+u\.|Hadrian|Comm|Antiq|Mytholog|Recherch|Pelasger|Journ|Topogr|Topograf|Geogr|Navig|Life of|Dialect|Annal|Transl|Discors|Voyage|Hist\.|Histoir|Lecture|Analys|Descript|\s+and\s+|Beschreibung|Itiner|Schrift|Antichit|Research|Diction|Discover|Reise|Viagg|Travel|Atlas)',foo)):
        continue
    if(re.search('(Acts|Afrique Ancienne|Arabs of the Arabs|philolog|Apocalypse|Corograf|Denkmäl|Della |Dell\' |Denkmal|Etymol|Exped|Exercitat|Explana|Fundgrub|Isaiah|Iscriz|Itin|Numism|Odes |Philolog|Statisti|Statues of|Uber |Urkund|Wanderzungen|Zeitung)',foo)):
        continue
    if(re.search('(Fasti|Lettres|Restes|Statist|Discourse|Book|Onom\.|Epistle|Stadiasm|Corrispond|Relations|Chronolog|Colonies|Tribes|survey|Chariots|commerce|Karte|Theolog|Review|Revue|Revist|Beiträg|Theophanes|Ausonian|Cynegetice|Disputat|Dorian|Italian|Judges|Aegyptiaca|Artemid|Asians|authorit|Bacchic|Basis |British|Decline|Dintorni|Dissert|Doctr\.|Etrusker|Fragment|Georgius|Joshua|Legionary|Peloponnesiaca|Preface|relations|Specimen|Tshina)',foo)):
        continue
    if(re.search('(Kings|Diccion|Verr\.|Olynth\.|Iliad|Corpus|Appendix|Chaldäer|Gall. Duo|Descr\.|Relazion|the Huns|Cosmograph|Bullettino|Arts|Battles|March from|Letters|illustrata|Excerpta|Gospels|Pianta della|Religion|Dial\.|Peripl\.|Urbewohner|Studie|Carte |Alterthums|Linguae|Chronica|Diss.|Nations|Cenotaphia|Saxons in England|Peintures|Prometheus|Chronicon|Question|Ortsnamen|Illustraz|Survey|Econom|Visit|Epist\.|Dict\.|Paulae|Fast. Amitern|Childe Harold|Spec. Rei|Meteorologics|Realwörterbuch|Geog\.|Epitaph|Ancient|Anecdot|Ascent of|Biograph|Bishop|Delizie|encyclop|Europaïsche|Gesch\.|Greeks in|Inscrift|Magazine|Marmora|Mythical|Period|Pheidias|Remark|Skizze|Stadias\.|Storia|\s+tracts|officers)',foo)):
        continue
    if(re.search('(Alex|Amor|Anab|Anal|Anns|Aurel|Caes|Claud|Deut|Epit|Erdk|Handb|Hymn|Idyll|Insc|Ital|Judg|Mith|Orat|Pers|Peut|Propempt|Prov|Pyth|Samn|Tech|Theb|Them)\.',foo)):
        continue
    if(re.search('(Anecd|Annot|Anton|Apol|Chron|Epod|Fragm|Gramm|Inscr|Mithr|Numid|Opusc|Paneg|Praef|Protr|Sever|Stud|Theag|Thes)\.',foo)):
        continue
    if(re.search('(Aegin|Agath|Archit|Beschr|Crass|Danub|Dionys|Einleit|Excerpt|Exod|Ezek|Germ|Gloss|Inset|Josh|Oeconom|Orat|Panegyr|Pesc|Phaed|Phil|Strab|Suppl|Vitell)\.',foo)):
        continue
    if(re.search('(Astrolog|Controv|Inscript)\.',foo)):
        continue
    
    i = i + 1
    if( re.search('\.\s+',foo) and not re.search('(S\.|St\.)',foo)):
        continue
    foo = re.sub('\.$','',foo)
    print(foo,file=outf)
    #print(i,titlelen[foo],titles[foo],foo,file=outf)
        
        
outf.close()
# Out:
# ethnics done
# places done
# 9167 32

# %%
'Loire' in placelist
# Out:
# True

# %%
l = '<title>Valmontone, Zagarolo</title>, and <title>Lugnano.</title>'

l = re.sub('(<title>[A-Z][a-zá]+)(,\s+)([A-Z][a-z]+</title>)','\g<1></title>\g<2><title>\g<3>',l)
l
l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3></title>\g<4><title>\g<5>',l)
l = re.sub('(<title>[A-Z][a-zá]+)([,\s]+or\s+|,\s+|[,\s]+and\s+)([A-Z][a-zá]+[\.]*</title>)','\g<1></title>\g<2><title>\g<3>',l)
l
# Out:
# '<title>Valmontone</title>, <title>Zagarolo</title>, and <title>Lugnano.</title>'
